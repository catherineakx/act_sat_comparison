# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
#
# **We Believe In Education Pte Ltd** (“company”) is a private tuition centre based in Singapore. In view of its resounding success in Singapore to help students excel in the GCE A-Level Examinations and get into prestigious local and overseas universities, the company is keen to expand its range of private education services into the United States.
#
# There are 2 major examinations in the United States, namely SAT and ACT. As part of its pilot programme *(though with limited budget)*, the company wishes to penetrate into the United States' market cautiously. For a start, it would like to provide tuition services in either SAT or ACT tuition service, and focusing on certain states in the country.
#
# As it is still relatively unknown in the USA, the company is looking to invest in advertising to create brand awareness. It is also allocating budget to award scholarships to deserving students, as part of its publicity plan.
#
# This project aims to identify the **tuition programme (either SAT or ACT) that the company should offer** as part of its pilot programme, as well as **states which are the most promising for the company to advertise its services to** - this includes the awarding of scholarships to deserving students.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# The datasets used for this analysis are as follows:
# - **ACT**: To understand the trend of participation rates and scores from 2017 to 2019
#     - [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
#     - [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
#     - [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
#
#
# - **SAT**: To understand the trend of participation rates and scores from 2017 to 2019
#     - [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
#     - [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
#     - [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# While more and more colleges are adopting test-optional admissions, which mean that ACT or SAT is not mandatory as an admission criteria, the demand to sign up for either ACT or SAT remains high. Even with the COVID-19 pandemic resulting in mass cancellations of SAT/ACT exams in 2020 due to the lack of appropriate examination venues, 1.1 million students from the class of 2020 took the SAT on a school day, up from almost 1 million in the class of 2019.(1)
#
# Additionally, with academic research highlighting the value of using SAT/ACT test scores as part of the admissions process, where they are used to compare studens from various schools, districts and states, all on the same playing field, they remain highly predictive of the students' success in college.(2)
#
# As the university admissions process stabilises post-pandemic in the long run, the College Board in SAT has stated that it will support the transition for all students to have the opportunity to participate in the tests and submit their scores.(3) Therefore, it is highly likely that there will be a continuous demand for SAT/ACT, and therefore the need for private tuition in a bid to boost up scores.
#
#
#
# Citations:
# - (1) https://www.theatlantic.com/ideas/archive/2020/09/even-coronavirus-cant-kill-sat-and-act/616360/
# - (2) https://edition.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html
# - (3) https://reports.collegeboard.org/sat-suite-program-results

# %% [markdown]
# ### Assumptions Used
#
# - The market for private education providers in United States is not yet saturated;
# - The market post COVID-19 pandemic will revert back to similar conditions as pre COVID-19 pandemic;
# - There will not be major changes in government or state policies in the near term, i.e. making SAT/ACT mandatory or option.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# To write a function that takes in values and returns the mean of the values

def compute_mean(values):
    n = len(values)
    mean_of_values = sum(values) / n
    return mean_of_values

# %%
# To create a list of numbers for testing the function

values = [10,12,14,16,18,20]

compute_mean(values)
# Out:
# 15.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# To write a function that takes in values and returns the standard deviation of the values

def compute_stddev(values):
    n = len(values)
    
    # To create an exit function if len(values) is less than 1
    if n<1: 
        return 0
    
    # To calculate the mean of values
    sum_of_values = 0
    count_of_values = 0
    for i in values:
        sum_of_values += i
        count_of_values += 1
    mean_of_values = sum_of_values / count_of_values
    
    # To calculate the sum of square difference from the mean
    sum_of_square_diff = 0
    for i in values:
        sum_of_square_diff += (i - mean_of_values) ** 2
    
    # To return the square root of the
    standard_deviation = (sum_of_square_diff / (count_of_values - 1)) ** 0.5
    return standard_deviation

# %%
# To create a list of numbers for testing the function

values = [10,12,14,16,18,20]

compute_stddev(values)
# Out:
# 3.7416573867739413

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# To write a function that takes in a string (containing a number and a percent symbol) and converts this to a float (decimal approx. of the percent)

def participation_to_float(percentage_string):
    participation = float(percentage_string[:-1])/100
    return participation

# %%
# To test if the participation_to_float(percentage_string) function works 

x = '30.5%'
participation_to_float(x)
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# To import the necessary libraries: 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# List of data to be explored: 
# (i) act_2017.csv
# (ii) sat_2017.csv
# (iii) act_2018.csv
# (iv) sat_2018.csv
# (v) act_2019.csv
# (vi) sat_2019.csv

# %% [markdown]
# #### Data Import & Cleaning - ACT 2017

# %%
# (i) 1. To read act_2017.csv and display the first 5 rows
act_2017 = pd.read_csv('data/act_2017.csv')
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
# (i) 2. To check for any missing values in act_2017
act_2017.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
# (i) 3. To obtain a summary of the values in each column in act_2017
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
# (i) 3. To check if the values in each row are unique in act_2017
act_2017['State'].is_unique
# Out:
# True

# %%
# (i) 3. To view a summary of act_2017 table - keep in mind the minimum & maximum possible values for each subject
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
# (i) 4. To fix any errors identified in 2 and 3 in act_2017
# Noted that that the 'Participation' column is not included in the table in 3, as the values are processed as a string with the percentage symbol included.
# Noted that there are 52 rows, even though the rows are unique

# %%
# (i) 5. To display the data types of each feature in act_2017
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
# (i) 6. To fix the 'Composite' column because it should be showing as a float for act_2017, instead of an object

# When the following function was run, error message indicated that one of the row value in the 'Composite' column is showing as '20.2x'
# act_2017['Composite'].astype(float)

# %%
# (i) 6. To replace '20.2x' in the 'Composite' column in act_2017
act_2017['Composite'] = act_2017['Composite'].replace(['20.2x'],float(20.2))

# %%
# (i) 6. To convert the 'Composite' column into a float in act_2017
act_2017['Composite'] = act_2017['Composite'].astype(float)

# %%
# (i) 6. To convert the 'Participation' column into a float in act_2017 using the participation_to_float(percentage_string) function
act_2017['Participation'] = act_2017['Participation'].map(lambda x: participation_to_float(x))

# %%
# (i) 6. To run a check on the new data types of each feature in act_2017
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
# (i) 7. To rename the columns in act_2017

act_2017.rename(columns = {
    'State': 'state',
    'Participation': 'act_participation_2017',
    'English': 'act_english_2017',
    'Math': 'act_math_2017',
    'Reading': 'act_reading_2017',
    'Science': 'act_science_2017',
    'Composite': 'act_composite_2017'},
               inplace=True)

act_2017.head()
# Out:
#       state  act_participation_2017  act_english_2017  act_math_2017  \
# 0  National                    0.60              20.3           20.7
# 1   Alabama                    1.00              18.9           18.4
# 2    Alaska                    0.65              18.7           19.8
# 3   Arizona                    0.62              18.6           19.8
# 4  Arkansas                    1.00              18.9           19.0
#
#    act_reading_2017  act_science_2017  act_composite_2017
# 0              21.4              21.0                21.0
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4

# %%
# (i) 8. To drop the 'National' row in act_2017 as it is not representative of a state 
act_2017.drop(0,inplace=True)

# %%
# (i) 8. To reset the index for act_2017
act_2017.reset_index(drop=True,inplace=True)

# %%
# (i) 8. To do a preview of the changes made to act_2017 
act_2017.head()
# Out:
#         state  act_participation_2017  act_english_2017  act_math_2017  \
# 0     Alabama                    1.00              18.9           18.4
# 1      Alaska                    0.65              18.7           19.8
# 2     Arizona                    0.62              18.6           19.8
# 3    Arkansas                    1.00              18.9           19.0
# 4  California                    0.31              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8

# %%
# (i) 8. To re-run a check to obtain a summary of the values in each column in act_2017 - there should only be 51 rows, inclusive of the header row
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   act_participation_2017  51 non-null     float64
#  2   act_english_2017        51 non-null     float64
#  3   act_math_2017           51 non-null     float64
#  4   act_reading_2017        51 non-null     float64
#  5   act_science_2017        51 non-null     float64
#  6   act_composite_2017      51 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# #### Data Import & Cleaning - SAT 2017

# %%
# (ii) 1. To read sat_2017.csv and display the first 5 rows
sat_2017 = pd.read_csv('data/sat_2017.csv')
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
# (ii) 2. To check for any missing values in sat_2017
sat_2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
# (ii) 3. To obtain a summary of the values in each column in sat_2017
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# (ii) 3. To check if the values in each row are unique in sat_2017
sat_2017['State'].is_unique
# Out:
# True

# %%
# (ii) 3. To view a summary of sat_2017 table - keep in mind the minimum & maximum possible values for each subject
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
# (ii) 4. To fix any errors identified in 2 and 3 in sat_2017
# Noted that that the 'Participation' column is not included in the table in 3, as the values are processed as a string with the percentage symbol included.

# %%
# (ii) 5. To display the data types of each feature in sat_2017
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# (ii) 6. To convert the 'Participation' column into a float in sat_2017 using the participation_to_float(percentage_string) function
sat_2017['Participation'] = sat_2017['Participation'].map(lambda x: participation_to_float(x))

# %%
# (ii) 6. To run a check on the new data types of each feature in sat_2017
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
# (ii) 7. To rename the columns in sat_2017

sat_2017.rename(columns = {
    'State': 'state',
    'Participation': 'sat_participation_2017',
    'Evidence-Based Reading and Writing': 'sat_reading_writing_2017',
    'Math': 'sat_math_2017',
    'Total': 'sat_total_2017'},inplace=True)

sat_2017.head()
# Out:
#         state  sat_participation_2017  sat_reading_writing_2017  \
# 0     Alabama                    0.05                       593
# 1      Alaska                    0.38                       547
# 2     Arizona                    0.30                       563
# 3    Arkansas                    0.03                       614
# 4  California                    0.53                       531
#
#    sat_math_2017  sat_total_2017
# 0            572            1165
# 1            533            1080
# 2            553            1116
# 3            594            1208
# 4            524            1055

# %%
# (ii) 8. To re-run a check to obtain a summary of the values in each column in sat_2017 - there should only be 51 rows, inclusive of the header row
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     51 non-null     object
#  1   sat_participation_2017    51 non-null     float64
#  2   sat_reading_writing_2017  51 non-null     int64
#  3   sat_math_2017             51 non-null     int64
#  4   sat_total_2017            51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# #### Data Import & Cleaning - Merging ACT 2017 and SAT 2017

# %%
# (i) & (ii) 9. To merge both act_2017 and sat_2017 together, and display the first 5 values

act_sat_2017 = pd.merge(act_2017, sat_2017, on = 'state', how = 'outer')
act_sat_2017.head()
# Out:
#         state  act_participation_2017  act_english_2017  act_math_2017  \
# 0     Alabama                    1.00              18.9           18.4
# 1      Alaska                    0.65              18.7           19.8
# 2     Arizona                    0.62              18.6           19.8
# 3    Arkansas                    1.00              18.9           19.0
# 4  California                    0.31              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8
#
#    sat_participation_2017  sat_reading_writing_2017  sat_math_2017  \
# 0                    0.05                       593            572
# ...

# %%
# (i) & (ii) 10. To obtain a summary of the values in each column in act_sat_2017 - there should only be 51 rows, inclusive of the header row
act_sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     51 non-null     object
#  1   act_participation_2017    51 non-null     float64
#  2   act_english_2017          51 non-null     float64
#  3   act_math_2017             51 non-null     float64
#  4   act_reading_2017          51 non-null     float64
#  5   act_science_2017          51 non-null     float64
#  6   act_composite_2017        51 non-null     float64
#  7   sat_participation_2017    51 non-null     float64
#  8   sat_reading_writing_2017  51 non-null     int64
#  9   sat_math_2017             51 non-null     int64
#  10  sat_total_2017            51 non-null     int64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 4.8+ KB

# %%
# (i) & (ii) 11. To save act_sat_2017 table as a csv file
act_sat_2017.to_csv('data/act_sat_2017.csv')

# %% [markdown]
# #### Data Import & Cleaning - ACT 2018

# %%
# (iii) 1. To read act_2018.csv and display the first 5 rows
act_2018 = pd.read_csv('data/act_2018.csv')
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
# (iii) 2. To check for any missing values in act_2018
act_2018.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
# (iii) 3. To obtain a summary of the values in each column in act_2018
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
# (iii) 3. To check if the values in each row are unique in act_2018
act_2018['State'].is_unique
# Out:
# False

# %%
# (iii) 3. To view a summary of act_2018 table
act_2018.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %%
# (iii) 4. To fix any errors identified in 2 and 3 in act_2018
# Noted that that the 'Participation' column is not included in the table in 3, as the values are processed as a string with the percentage symbol included.
# Noted that the row values in column 'State' is not unique
# Noted that 'District of columbia' is not written in the correct format

# %%
# (iii) 4. To remove duplicated rows in act_2018
act_2018.drop_duplicates(subset=['State'], inplace=True)

# %%
# (iii) 4. To reset the index for act_2018
act_2018.reset_index(drop=True,inplace=True)

# %%
# (iii) 4. To write 'District of columbia' in the correct format

act_2018['State'] = act_2018['State'].str.replace('District of columbia','District of Columbia')

# %%
# (iii) 5. To display the data types of each feature in act_2018
act_2018.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
# (iii) 6. To convert the 'Participation' column into a float in act_2018 using the participation_to_float(percentage_string) function
act_2018['Participation'] = act_2018['Participation'].map(lambda x: participation_to_float(x))

# %%
# (iii) 6. To run a check on the new data types of each feature in act_2018
act_2018.dtypes
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
# (iii) 7. To rename the columns in act_2018

act_2018.rename(columns = {
    'State': 'state',
    'Participation': 'act_participation_2018',
    'Composite': 'act_composite_2018'},
               inplace=True)

act_2018.head()
# Out:
#         state  act_participation_2018  act_composite_2018
# 0     Alabama                    1.00                19.1
# 1      Alaska                    0.33                20.8
# 2     Arizona                    0.66                19.2
# 3    Arkansas                    1.00                19.4
# 4  California                    0.27                22.7

# %%
# (iii) 8. To re-run a check to obtain a summary of the values in each column in act_2018 - there should only be 51 rows, inclusive of the header row
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   act_participation_2018  51 non-null     float64
#  2   act_composite_2018      51 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# #### Data Import & Cleaning - SAT 2018

# %%
# (iv) 1. To read sat_2018.csv and display the first 5 rows
sat_2018 = pd.read_csv('data/sat_2018.csv')
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
# (iv) 2. To check for any missing values in sat_2018
sat_2018.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
# (iv) 3. To obtain a summary of the values in each column in sat_2018
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# (iv) 3. To check if the values in each row are unique in sat_2018
sat_2018['State'].is_unique
# Out:
# True

# %%
# (iv) 3. To view a summary of sat_2018 table - keep in mind the minimum & maximum possible values for each subject
sat_2018.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
# (iv) 4. To fix any errors identified in 2 and 3 in sat_2018
# Noted that that the 'Participation' column is not included in the table in 3, as the values are processed as a string with the percentage symbol included.

# %%
# (iv) 5. To display the data types of each feature in sat_2018
sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# (iv) 6. To convert the 'Participation' column into a float in sat_2018 using the participation_to_float(percentage_string) function
sat_2018['Participation'] = sat_2018['Participation'].map(lambda x: participation_to_float(x))

# %%
# (iv) 6. To run a check on the new data types of each feature in sat_2018
sat_2018.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
# (iv) 7. To rename the columns in sat_2018

sat_2018.rename(columns = {
    'State': 'state',
    'Participation': 'sat_participation_2018',
    'Evidence-Based Reading and Writing': 'sat_reading_writing_2018',
    'Math': 'sat_math_2018',
    'Total': 'sat_total_2018'},inplace=True)

sat_2018.head()
# Out:
#         state  sat_participation_2018  sat_reading_writing_2018  \
# 0     Alabama                    0.06                       595
# 1      Alaska                    0.43                       562
# 2     Arizona                    0.29                       577
# 3    Arkansas                    0.05                       592
# 4  California                    0.60                       540
#
#    sat_math_2018  sat_total_2018
# 0            571            1166
# 1            544            1106
# 2            572            1149
# 3            576            1169
# 4            536            1076

# %%
# (iv) 8. To re-run a check to obtain a summary of the values in each column in sat_2018 - there should only be 51 rows, inclusive of the header row
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     51 non-null     object
#  1   sat_participation_2018    51 non-null     float64
#  2   sat_reading_writing_2018  51 non-null     int64
#  3   sat_math_2018             51 non-null     int64
#  4   sat_total_2018            51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# #### Data Import & Cleaning - Merging ACT 2018 and SAT 2018

# %%
# (iii) & (iv) 9. To merge both act_2018 and sat_2018 together, and display the first 5 values

act_sat_2018 = pd.merge(act_2018, sat_2018, on = 'state', how = 'outer')
act_sat_2018.head()
# Out:
#         state  act_participation_2018  act_composite_2018  \
# 0     Alabama                    1.00                19.1
# 1      Alaska                    0.33                20.8
# 2     Arizona                    0.66                19.2
# 3    Arkansas                    1.00                19.4
# 4  California                    0.27                22.7
#
#    sat_participation_2018  sat_reading_writing_2018  sat_math_2018  \
# 0                    0.06                       595            571
# 1                    0.43                       562            544
# 2                    0.29                       577            572
# 3                    0.05                       592            576
# 4                    0.60                       540            536
#
#    sat_total_2018
# 0            1166
# 1            1106
# 2            1149
# 3            1169
# 4            1076

# %%
# (iii) & (iv) 10. To obtain a summary of the values in each column in act_sat_2018 - there should only be 51 rows, inclusive of the header row
act_sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     51 non-null     object
#  1   act_participation_2018    51 non-null     float64
#  2   act_composite_2018        51 non-null     float64
#  3   sat_participation_2018    51 non-null     float64
#  4   sat_reading_writing_2018  51 non-null     int64
#  5   sat_math_2018             51 non-null     int64
#  6   sat_total_2018            51 non-null     int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.2+ KB

# %%
# (iii) & (iv) 11. To save act_sat_2018 table as a csv file
act_sat_2018.to_csv('data/act_sat_2018.csv')

# %% [markdown]
# #### Data Import & Cleaning - ACT 2019

# %%
# (v) 1. To read act_2019.csv and display the first 5 rows
act_2019 = pd.read_csv('data/act_2019.csv')
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
# (v) 2. To check for any missing values in act_2019
act_2019.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
# (v) 3. To obtain a summary of the values in each column in act_2019
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
# (v) 3. To check if the values in each row are unique in act_2019
act_2019['State'].is_unique
# Out:
# True

# %%
# (v) 3. To view a summary of act_2019 table - keep in mind the minimum & maximum possible values for each subject
act_2019.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000

# %%
# (v) 4. To fix any errors identified in 2 and 3 in act_2019
# Noted that that the 'Participation' column is not included in the table in 3, as the values are processed as a string with the percentage symbol included.
# Noted that there are 52 rows, even though the rows are unique

# %%
# (v) 5. To display the data types of each feature in act_2019
act_2019.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
# (v) 6. To convert the 'Participation' column into a float in act_2019 using the participation_to_float(percentage_string) function
act_2019['Participation'] = act_2019['Participation'].map(lambda x: participation_to_float(x))

# %%
# (v) 6. To run a check on the new data types of each feature in act_2019
act_2019.dtypes
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
# (v) 7. To rename the columns in act_2019

act_2019.rename(columns = {
    'State': 'state',
    'Participation': 'act_participation_2019',
    'Composite': 'act_composite_2019'},
               inplace=True)

act_2019.head()
# Out:
#         state  act_participation_2019  act_composite_2019
# 0     Alabama                    1.00                18.9
# 1      Alaska                    0.38                20.1
# 2     Arizona                    0.73                19.0
# 3    Arkansas                    1.00                19.3
# 4  California                    0.23                22.6

# %%
# (v) 8. To do a check and display the last 5 rows in act_2019
act_2019.tail()
# Out:
#             state  act_participation_2019  act_composite_2019
# 47     Washington                    0.24                22.1
# 48  West Virginia                    0.49                20.8
# 49      Wisconsin                    1.00                20.3
# 50        Wyoming                    1.00                19.8
# 51       National                    0.52                20.7

# %%
# (v) 8. To drop the 'National' row in act_2019 as it is not representative of a state 
act_2019.drop(51,inplace=True)

# %%
# (v) 8. To do a preview of the changes made to act_2019
act_2019.tail()
# Out:
#             state  act_participation_2019  act_composite_2019
# 46       Virginia                    0.21                24.0
# 47     Washington                    0.24                22.1
# 48  West Virginia                    0.49                20.8
# 49      Wisconsin                    1.00                20.3
# 50        Wyoming                    1.00                19.8

# %%
# (v) 8. To re-run a check to obtain a summary of the values in each column in act_2019 - there should only be 51 rows, inclusive of the header row
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   act_participation_2019  51 non-null     float64
#  2   act_composite_2019      51 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.6+ KB

# %% [markdown]
# #### Data Import & Cleaning - SAT 2019

# %%
# (vi) 1. To read sat_2019.csv and display the first 5 rows
sat_2019 = pd.read_csv('data/sat_2019.csv')
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
# (vi) 2. To check for any missing values in sat_2019
sat_2019.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
# (vi) 3. To obtain a summary of the values in each column in sat_2019
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
# (vi) 3. To check if the values in each row are unique in sat_2019
sat_2019['State'].is_unique
# Out:
# True

# %%
# (vi) 3. To view a summary of sat_2019 table - keep in mind the minimum & maximum possible values for each subject
sat_2019.describe()
# Out:
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %%
# (vi) 4. To fix any errors identified in 2 and 3 in sat_2019
# Noted that that the 'Participation' column is not included in the table in 3, as the values are processed as a string with the percentage symbol included.
# Noted that there are 53 rows, even though the rows are unique

# %%
# (vi) 5. To display the data types of each feature in sat_2019
sat_2019.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
# (vi) 6. To convert the 'Participation' column into a float in sat_2019 using the participation_to_float(percentage_string) function

# When the following function was run, error message indicated that there are values in the 'Participation Rate' which are not considered string
# sat_2019['Participation Rate'] = sat_2019['Participation Rate'].map(lambda x: participation_to_float(x))

# %%
# (vi) 6. To do a sort based on 'Participation Rate' column in sat_2019
sat_2019['Participation Rate'].sort_values(ascending=False).head()
# Out:
# 47      —
# 39      —
# 50    99%
# 19    99%
# 29    95%
# Name: Participation Rate, dtype: object

# %%
# (vi) 6. To drop row index 39 in sat_2019, as it was causing the error in 6
sat_2019.drop(39,inplace=True)

# %%
# (vi) 6. To drop row index 47 in sat_2019, as it was causing the error in 6
sat_2019.drop(47,inplace=True)

# %%
# (vi) 6. To convert the 'Participation' column into a float in sat_2019 using the participation_to_float(percentage_string) function
sat_2019['Participation Rate'] = sat_2019['Participation Rate'].map(lambda x: participation_to_float(x))

# %%
# (vi) 6. To run a check on the new data types of each feature in sat_2019
sat_2019.dtypes
# Out:
# State                  object
# Participation Rate    float64
# EBRW                    int64
# Math                    int64
# Total                   int64
# dtype: object

# %%
# (vi) 7. To rename the columns in sat_2019

sat_2019.rename(columns = {
    'State': 'state',
    'Participation Rate': 'sat_participation_2019',
    'EBRW': 'sat_reading_writing_2019',
    'Math': 'sat_math_2019',
    'Total': 'sat_total_2019'},inplace=True)

sat_2019.head()
# Out:
#         state  sat_participation_2019  sat_reading_writing_2019  \
# 0     Alabama                    0.07                       583
# 1      Alaska                    0.41                       556
# 2     Arizona                    0.31                       569
# 3    Arkansas                    0.06                       582
# 4  California                    0.63                       534
#
#    sat_math_2019  sat_total_2019
# 0            560            1143
# 1            541            1097
# 2            565            1134
# 3            559            1141
# 4            531            1065

# %%
# (vi) 8. To re-run a check to obtain a summary of the values in each column in sat_2019 - there should only be 51 rows, inclusive of the header row
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     51 non-null     object
#  1   sat_participation_2019    51 non-null     float64
#  2   sat_reading_writing_2019  51 non-null     int64
#  3   sat_math_2019             51 non-null     int64
#  4   sat_total_2019            51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# #### Data Import & Cleaning - Merging ACT 2019 and SAT 2019

# %%
# (v) & (vi) 9. To merge both act_2019 and sat_2019 together, and display the first 5 values

act_sat_2019 = pd.merge(act_2019, sat_2019, on = 'state', how = 'outer')
act_sat_2019.head()
# Out:
#         state  act_participation_2019  act_composite_2019  \
# 0     Alabama                    1.00                18.9
# 1      Alaska                    0.38                20.1
# 2     Arizona                    0.73                19.0
# 3    Arkansas                    1.00                19.3
# 4  California                    0.23                22.6
#
#    sat_participation_2019  sat_reading_writing_2019  sat_math_2019  \
# 0                    0.07                       583            560
# 1                    0.41                       556            541
# 2                    0.31                       569            565
# 3                    0.06                       582            559
# 4                    0.63                       534            531
#
#    sat_total_2019
# 0            1143
# 1            1097
# 2            1134
# 3            1141
# 4            1065

# %%
# (v) & (vi) 10. To obtain a summary of the values in each column in act_sat_2019 - there should only be 51 rows, inclusive of the header row
act_sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     51 non-null     object
#  1   act_participation_2019    51 non-null     float64
#  2   act_composite_2019        51 non-null     float64
#  3   sat_participation_2019    51 non-null     float64
#  4   sat_reading_writing_2019  51 non-null     int64
#  5   sat_math_2019             51 non-null     int64
#  6   sat_total_2019            51 non-null     int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.2+ KB

# %%
# (v) & (vi) 11. To save act_sat_2019 table as a csv file
act_sat_2019.to_csv('data/act_sat_2019.csv')

# %% [markdown]
# #### Data Import & Cleaning - Merging ACT 2017, SAT 2017, ACT 2018 and SAT 2018

# %%
# (i), (ii), (iii), (iv) 9. To merge both act_sat_2017 and act_sat_2018 together, and display the first 5 values

act_sat_2017_2018 = pd.merge(act_sat_2017, act_sat_2018, on = 'state', how = 'outer')
act_sat_2017_2018.head()
# Out:
#         state  act_participation_2017  act_english_2017  act_math_2017  \
# 0     Alabama                    1.00              18.9           18.4
# 1      Alaska                    0.65              18.7           19.8
# 2     Arizona                    0.62              18.6           19.8
# 3    Arkansas                    1.00              18.9           19.0
# 4  California                    0.31              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8
#
#    sat_participation_2017  sat_reading_writing_2017  sat_math_2017  \
# 0                    0.05                       593            572
# ...

# %%
# (i), (ii), (iii), (iv) 10. To obtain a summary of the values in each column in act_sat_2017_2018 - there should only be 51 rows, inclusive of the header row
act_sat_2017_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     51 non-null     object
#  1   act_participation_2017    51 non-null     float64
#  2   act_english_2017          51 non-null     float64
#  3   act_math_2017             51 non-null     float64
#  4   act_reading_2017          51 non-null     float64
#  5   act_science_2017          51 non-null     float64
#  6   act_composite_2017        51 non-null     float64
#  7   sat_participation_2017    51 non-null     float64
#  8   sat_reading_writing_2017  51 non-null     int64
#  9   sat_math_2017             51 non-null     int64
#  10  sat_total_2017            51 non-null     int64
#  11  act_participation_2018    51 non-null     float64
#  12  act_composite_2018        51 non-null     float64
# ...

# %%
# (i), (ii), (iii), (iv) 11. To save act_sat_2017_2018 table as a csv file 
act_sat_2017_2018.to_csv('data/act_sat_2017_2018.csv')

# %% [markdown]
# #### Data Import & Cleaning - Merging ACT 2018, SAT 2018, ACT 2019 and SAT 2019

# %%
# (iii), (iv), (v), (vi) 9. To merge both act_sat_2018 and act_sat_2019 together, and display the first 5 values

act_sat_2018_2019 = pd.merge(act_sat_2018, act_sat_2019, on = 'state', how = 'outer')
act_sat_2018_2019.head()
# Out:
#         state  act_participation_2018  act_composite_2018  \
# 0     Alabama                    1.00                19.1
# 1      Alaska                    0.33                20.8
# 2     Arizona                    0.66                19.2
# 3    Arkansas                    1.00                19.4
# 4  California                    0.27                22.7
#
#    sat_participation_2018  sat_reading_writing_2018  sat_math_2018  \
# 0                    0.06                       595            571
# 1                    0.43                       562            544
# 2                    0.29                       577            572
# 3                    0.05                       592            576
# 4                    0.60                       540            536
#
#    sat_total_2018  act_participation_2019  act_composite_2019  \
# 0            1166                    1.00                18.9
# 1            1106                    0.38                20.1
# ...

# %%
# (iii), (iv), (v), (vi) 10. To obtain a summary of the values in each column in act_sat_2018_2019 - there should only be 51 rows, inclusive of the header row
act_sat_2018_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     51 non-null     object
#  1   act_participation_2018    51 non-null     float64
#  2   act_composite_2018        51 non-null     float64
#  3   sat_participation_2018    51 non-null     float64
#  4   sat_reading_writing_2018  51 non-null     int64
#  5   sat_math_2018             51 non-null     int64
#  6   sat_total_2018            51 non-null     int64
#  7   act_participation_2019    51 non-null     float64
#  8   act_composite_2019        51 non-null     float64
#  9   sat_participation_2019    51 non-null     float64
#  10  sat_reading_writing_2019  51 non-null     int64
#  11  sat_math_2019             51 non-null     int64
#  12  sat_total_2019            51 non-null     int64
# dtypes: float64(6), int64(6), object(1)
# ...

# %%
# (iii), (iv), (v), (vi) 11. To save act_sat_2018_2019 table as a csv file 
act_sat_2018_2019.to_csv('data/act_sat_2018_2019.csv')

# %% [markdown]
# #### Data Import & Cleaning - Merging ACT 2017, SAT 2017, ACT 2018, SAT 2018, ACT 2019 and SAT 2019

# %%
# (i), (ii), (iii), (iv), (v), (vi) 9. To merge both act_sat_2017_2018 and act_sat_2019 together, and display the first 5 values

act_sat_all = pd.merge(act_sat_2017_2018, act_sat_2019, on = 'state', how = 'outer')
act_sat_all.head()
# Out:
#         state  act_participation_2017  act_english_2017  act_math_2017  \
# 0     Alabama                    1.00              18.9           18.4
# 1      Alaska                    0.65              18.7           19.8
# 2     Arizona                    0.62              18.6           19.8
# 3    Arkansas                    1.00              18.9           19.0
# 4  California                    0.31              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8
#
#    sat_participation_2017  sat_reading_writing_2017  sat_math_2017  ...  \
# 0                    0.05                       593            572  ...
# ...

# %%
# (i), (ii), (iii), (iv), (v), (vi) 10. To obtain a summary of the values in each column in act_sat_all - there should only be 51 rows, inclusive of the header row
act_sat_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     51 non-null     object
#  1   act_participation_2017    51 non-null     float64
#  2   act_english_2017          51 non-null     float64
#  3   act_math_2017             51 non-null     float64
#  4   act_reading_2017          51 non-null     float64
#  5   act_science_2017          51 non-null     float64
#  6   act_composite_2017        51 non-null     float64
#  7   sat_participation_2017    51 non-null     float64
#  8   sat_reading_writing_2017  51 non-null     int64
#  9   sat_math_2017             51 non-null     int64
#  10  sat_total_2017            51 non-null     int64
#  11  act_participation_2018    51 non-null     float64
#  12  act_composite_2018        51 non-null     float64
# ...

# %%
# (i), (ii), (iii), (iv), (v), (vi) 11. To save act_sat_all table as a csv file
act_sat_all.to_csv('data/act_sat_all.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*object*|ACT 2017-2019, SAT 2017-2019|State in United States|
# |**act_participation_2017**|*float*|ACT 2017|Statewide ACT Participation Rate, 2017|
# |**act_english_2017**|*float*|ACT 2017|State mean score, ACT English (1-36), 2017|
# |**act_math_2017**|*float*|ACT 2017|State mean score, ACT Mean (1-36), 2017|
# |**act_reading_2017**|*float*|ACT 2017|State mean score, ACT Reading (1-36), 2017|
# |**act_science_2017**|*float*|ACT 2017|State mean score, ACT Science (1-36), 2017|
# |**act_composite_2017**|*float*|ACT 2017|State mean ACT Composite Score (1-36), 2017|
# |**sat_participation_2017**|*float*|SAT 2017|Statewide SAT Participation Rate, 2017|
# |**sat_reading_writing_2017**|*integer*|SAT 2017|State mean score, SAT Evidence-Based Reading and Writing (200-800), 2017|
# |**sat_math_2017**|*integer*|SAT 2017|State mean score, SAT Math (200-800), 2017|
# |**sat_total_2017**|*integer*|SAT 2017|State mean total SAT score (400-1600), 2017|
# |**act_participation_2018**|*float*|ACT 2018|Statewide ACT Participation Rate, 2018|
# |**act_composite_2018**|*float*|ACT 2018|State mean ACT Composite Score (1-36), 2018|
# |**sat_participation_2018**|*float*|SAT 2018|Statewide SAT Participation Rate, 2018|
# |**sat_reading_writing_2018**|*integer*|SAT 2018|State mean score, SAT Evidence-Based Reading and Writing (200-800), 2018|
# |**sat_math_2018**|*integer*|SAT 2018|State mean score, SAT Math (200-800), 2018|
# |**sat_total_2018**|*integer*|SAT 2018|State mean total SAT score (400-1600), 2018|
# |**act_participation_2019**|*float*|ACT 2019|Statewide ACT Participation Rate, 2019|
# |**act_composite_2019**|*float*|ACT 2019|State mean ACT Composite Score (1-36), 2019|
# |**sat_participation_2019**|*float*|SAT 2019|Statewide SAT Participation Rate, 2019|
# |**sat_reading_writing_2019**|*integer*|SAT 2019|State mean score, SAT Evidence-Based Reading and Writing (200-800), 2019|
# |**sat_math_2019**|*integer*|SAT 2019|State mean score, SAT Math (200-800), 2019|
# |**sat_total_2019**|*integer*|SAT 2019|State mean total SAT score (400-1600), 2019|
# |**act_participation_change_2017_2018**|*float*|ACT 2017 & 2018|Change in ACT Participation Rate, 2017-2018|
# |**act_participation_change_2018_2019**|*float*|ACT 2018 & 2019|Change in ACT Participation Rate, 2018-2019|
# |**sat_participation_change_2017_2018**|*float*|SAT 2017 & 2018|Change in SAT Participation Rate, 2017-2018|
# |**sat_participation_change_2018_2019**|*float*|SAT 2018 & 2019|Change in SAT Participation Rate, 2018-2019|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### 1. Summary Statistics

# %%
# To transpose the output of act_sat_all for a quick overview of each numeric column in the dataframe
act_sat_all.describe().T
# Out:
#                           count         mean        std     min       25%  \
# act_participation_2017     51.0     0.652549   0.321408    0.08     0.310
# act_english_2017           51.0    20.931373   2.353677   16.30    19.000
# act_math_2017              51.0    21.182353   1.981989   18.00    19.400
# act_reading_2017           51.0    22.013725   2.067271   18.10    20.450
# act_science_2017           51.0    21.041176   3.182463    2.30    19.900
# act_composite_2017         51.0    21.519608   2.020695   17.80    19.800
# sat_participation_2017     51.0     0.398039   0.352766    0.02     0.040
# sat_reading_writing_2017   51.0   569.117647  45.666901  482.00   533.500
# sat_math_2017              51.0   547.627451  84.909119   52.00   522.000
# sat_total_2017             51.0  1126.098039  92.494812  950.00  1055.500
# act_participation_2018     51.0     0.617255   0.340371    0.07     0.285
# act_composite_2018         51.0    21.496078   2.111583   17.70    19.950
# ...

# %% [markdown]
# ### 2. Use a dictionary comprehension to apply the standard deviation function created to each numeric column in the dataframe

# %%
# To create a dictionary containing the numeric columns in the dataframe (as the key), and their respective standard deviation (as the value).
sd = {x: compute_stddev(act_sat_all[x]) for x in act_sat_all.columns if act_sat_all[x].dtypes != object}

# %%
# To display the dictionary in sd
sd
# Out:
# {'act_participation_2017': 0.32140842015886834,
#  'act_english_2017': 2.35367713980303,
#  'act_math_2017': 1.9819894936505533,
#  'act_reading_2017': 2.0672706264873146,
#  'act_science_2017': 3.182462975155452,
#  'act_composite_2017': 2.020694891154341,
#  'sat_participation_2017': 0.35276632270013036,
#  'sat_reading_writing_2017': 45.66690138768932,
#  'sat_math_2017': 84.90911865855486,
#  'sat_total_2017': 92.49481172519046,
#  'act_participation_2018': 0.34037084734960815,
#  'act_composite_2018': 2.111583366510896,
#  'sat_participation_2018': 0.37314256330391965,
#  'sat_reading_writing_2018': 47.50262737831599,
#  'sat_math_2018': 47.77262322095955,
#  'sat_total_2018': 94.15508275097599,
#  'act_participation_2019': 0.34515890060473114,
#  'act_composite_2019': 2.1945225931315235,
#  'sat_participation_2019': 0.38747599546142664,
#  'sat_reading_writing_2019': 46.24803546437109,
#  'sat_math_2019': 51.29055258343124,
#  'sat_total_2019': 97.1979100880785}

# %% [markdown]
# ### 3. Investigating trends in the data

# %% [markdown]
# #### (1) Which states have the highest and lowest participation rates for ACT and SAT, across 2017, 2018 and 2019?

# %% [markdown]
# - To identify states with the highest participation rates, we will consider the top 25th percentile (i.e. top 13).
# - To identify states with the lowest participation rates, we will consider the bottom 25th percentile (i.e. bottom 13).

# %%
# To compute the number of states (out of 50) which fall within the range of 25th percentile
0.25*50
# Out:
# 12.5

# %% [markdown]
# **Participation rates for ACT in 2017, 2018 and 2019**

# %%
# To identify states with the lowest participation rates for ACT in 2017
act_sat_all.sort_values('act_participation_2017')[['state','act_participation_2017']].head(13)
# Out:
#             state  act_participation_2017
# 19          Maine                    0.08
# 29  New Hampshire                    0.18
# 7        Delaware                    0.18
# 39   Rhode Island                    0.21
# 38   Pennsylvania                    0.23
# 20       Maryland                    0.28
# 45        Vermont                    0.29
# 21  Massachusetts                    0.29
# 22       Michigan                    0.29
# 46       Virginia                    0.29
# 47     Washington                    0.29
# 4      California                    0.31
# 32       New York                    0.31

# %%
# To identify states with the highest participation rates for ACT in 2017
act_sat_all.sort_values('act_participation_2017', ascending=False)[['state','act_participation_2017']].head(20)
# Out:
#              state  act_participation_2017
# 0          Alabama                    1.00
# 17        Kentucky                    1.00
# 49       Wisconsin                    1.00
# 44            Utah                    1.00
# 42       Tennessee                    1.00
# 40  South Carolina                    1.00
# 36        Oklahoma                    1.00
# 33  North Carolina                    1.00
# 28          Nevada                    1.00
# 26         Montana                    1.00
# 24     Mississippi                    1.00
# 23       Minnesota                    1.00
# 18       Louisiana                    1.00
# 25        Missouri                    1.00
# 50         Wyoming                    1.00
# 5         Colorado                    1.00
# 3         Arkansas                    1.00
# 34    North Dakota                    0.98
# 13        Illinois                    0.93
# 11          Hawaii                    0.90

# %% [markdown]
# Observations for ACT in 2017:
# - Maine has the lowest participation rate at 8%, followed by New Hamsphire and Delaware at 18%;
# - There are 17 states with 100% participation, i.e. Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, North Carolina, Nevada, Montana, Mississippi, Minnesota, Louisiana, Missouri, Wyoming, Colorado, Arkansas.

# %%
# To identify states with the lowest participation rates for ACT in 2018
act_sat_all.sort_values('act_participation_2018')[['state','act_participation_2018']].head(13)
# Out:
#             state  act_participation_2018
# 19          Maine                    0.07
# 39   Rhode Island                    0.15
# 29  New Hampshire                    0.16
# 7        Delaware                    0.17
# 38   Pennsylvania                    0.20
# 22       Michigan                    0.22
# 47     Washington                    0.24
# 45        Vermont                    0.24
# 46       Virginia                    0.24
# 21  Massachusetts                    0.25
# 6     Connecticut                    0.26
# 4      California                    0.27
# 32       New York                    0.27

# %%
# To identify states with the highest participation rates for ACT in 2018
act_sat_all.sort_values('act_participation_2018', ascending=False)[['state','act_participation_2018']].head(20)
# Out:
#              state  act_participation_2018
# 0          Alabama                    1.00
# 17        Kentucky                    1.00
# 49       Wisconsin                    1.00
# 44            Utah                    1.00
# 42       Tennessee                    1.00
# 40  South Carolina                    1.00
# 36        Oklahoma                    1.00
# 35            Ohio                    1.00
# 33  North Carolina                    1.00
# 28          Nevada                    1.00
# 27        Nebraska                    1.00
# 26         Montana                    1.00
# 24     Mississippi                    1.00
# 18       Louisiana                    1.00
# 25        Missouri                    1.00
# 50         Wyoming                    1.00
# 3         Arkansas                    1.00
# 23       Minnesota                    0.99
# 34    North Dakota                    0.98
# 11          Hawaii                    0.89

# %% [markdown]
# Observations for ACT in 2018:
# - A similar trend as those in 2017 is observed for 2018;
# - Maine has the lowest participation rate at 7%, followed by Rhode Island at 15%;
# - There are still 17 states with 100% participation, albeit some differences in states as compared to those in 2017 i.e. Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, Ohio, North Carolina, Nevada, Nebraska, Montana, Mississippi, Louisiana, Missouri, Wyoming, Arkansas.

# %%
# To identify states with the lowest participation rates for ACT in 2019
act_sat_all.sort_values('act_participation_2019')[['state','act_participation_2019']].head(13)
# Out:
#             state  act_participation_2019
# 19          Maine                    0.06
# 39   Rhode Island                    0.12
# 7        Delaware                    0.13
# 29  New Hampshire                    0.14
# 38   Pennsylvania                    0.17
# 22       Michigan                    0.19
# 45        Vermont                    0.20
# 46       Virginia                    0.21
# 21  Massachusetts                    0.21
# 32       New York                    0.22
# 6     Connecticut                    0.22
# 4      California                    0.23
# 47     Washington                    0.24

# %%
# To identify states with the highest participation rates for ACT in 2019
act_sat_all.sort_values('act_participation_2019', ascending=False)[['state','act_participation_2019']].head(20)
# Out:
#              state  act_participation_2019
# 0          Alabama                    1.00
# 17        Kentucky                    1.00
# 49       Wisconsin                    1.00
# 44            Utah                    1.00
# 42       Tennessee                    1.00
# 36        Oklahoma                    1.00
# 35            Ohio                    1.00
# 33  North Carolina                    1.00
# 28          Nevada                    1.00
# 27        Nebraska                    1.00
# 26         Montana                    1.00
# 24     Mississippi                    1.00
# 18       Louisiana                    1.00
# 50         Wyoming                    1.00
# 3         Arkansas                    1.00
# 34    North Dakota                    0.96
# 23       Minnesota                    0.95
# 25        Missouri                    0.82
# 11          Hawaii                    0.80
# 40  South Carolina                    0.78

# %% [markdown]
# Observations for ACT in 2019:
# - Again, a similar trend as those in 2017 and 2018 is observed for 2019;
# - Maine has the lowest participation rate at 6%, followed by Rhode Island at 12%;
# - There are 15 states with 100% participation - slight drop in number of states as compared to 2017 and 2018 - i.e. Alabama, Kentucky, Wisconsin, Utah, Tennessee, Oklahoma, Ohio, North Carolina, Nevada, Nebraska, Montana, Mississippi, Louisiana, Wyoming, Arkansas.

# %% [markdown]
# **Participation rates for SAT in 2017, 2018 and 2019**

# %%
# To identify states with the lowest participation rates for SAT in 2017
act_sat_all.sort_values('sat_participation_2017')[['state','sat_participation_2017']].head(20)
# Out:
#            state  sat_participation_2017
# 34  North Dakota                    0.02
# 24   Mississippi                    0.02
# 15          Iowa                    0.02
# 25      Missouri                    0.03
# 44          Utah                    0.03
# 41  South Dakota                    0.03
# 27      Nebraska                    0.03
# 49     Wisconsin                    0.03
# 23     Minnesota                    0.03
# 50       Wyoming                    0.03
# 3       Arkansas                    0.03
# 16        Kansas                    0.04
# 17      Kentucky                    0.04
# 18     Louisiana                    0.04
# 0        Alabama                    0.05
# 42     Tennessee                    0.05
# 36      Oklahoma                    0.07
# 13      Illinois                    0.09
# 26       Montana                    0.10
# 5       Colorado                    0.11

# %%
# To identify states with the highest participation rates for SAT in 2017
act_sat_all.sort_values('sat_participation_2017',ascending=False)[['state','sat_participation_2017']].head(13)
# Out:
#                    state  sat_participation_2017
# 8   District of Columbia                    1.00
# 22              Michigan                    1.00
# 6            Connecticut                    1.00
# 7               Delaware                    1.00
# 29         New Hampshire                    0.96
# 19                 Maine                    0.95
# 12                 Idaho                    0.93
# 9                Florida                    0.83
# 21         Massachusetts                    0.76
# 39          Rhode Island                    0.71
# 30            New Jersey                    0.70
# 20              Maryland                    0.69
# 32              New York                    0.67

# %% [markdown]
# Observations for SAT in 2017:
# - There are 3 states with the lowest participation rate of 2%, i.e. North Dakota, Mississippi and Iowa;
# - There are 4 states with the highest partipcation rate of 100%, i.e. District of Columbia, Michigan, Connecticut and Delaware.

# %%
# To identify states with the lowest participation rates for SAT in 2018
act_sat_all.sort_values('sat_participation_2018')[['state','sat_participation_2018']].head(20)
# Out:
#            state  sat_participation_2018
# 34  North Dakota                    0.02
# 50       Wyoming                    0.03
# 41  South Dakota                    0.03
# 27      Nebraska                    0.03
# 49     Wisconsin                    0.03
# 24   Mississippi                    0.03
# 15          Iowa                    0.03
# 44          Utah                    0.04
# 23     Minnesota                    0.04
# 18     Louisiana                    0.04
# 17      Kentucky                    0.04
# 16        Kansas                    0.04
# 25      Missouri                    0.04
# 3       Arkansas                    0.05
# 0        Alabama                    0.06
# 42     Tennessee                    0.06
# 36      Oklahoma                    0.08
# 26       Montana                    0.10
# 31    New Mexico                    0.16
# 35          Ohio                    0.18

# %%
# To identify states with the highest participation rates for SAT in 2018
act_sat_all.sort_values('sat_participation_2018',ascending=False)[['state','sat_participation_2018']].head(13)
# Out:
#                    state  sat_participation_2018
# 5               Colorado                    1.00
# 6            Connecticut                    1.00
# 7               Delaware                    1.00
# 22              Michigan                    1.00
# 12                 Idaho                    1.00
# 19                 Maine                    0.99
# 13              Illinois                    0.99
# 39          Rhode Island                    0.97
# 29         New Hampshire                    0.96
# 8   District of Columbia                    0.92
# 30            New Jersey                    0.82
# 21         Massachusetts                    0.80
# 32              New York                    0.79

# %% [markdown]
# Observations for SAT in 2018:
# - North Dakota has the lowest participation rate at 2%, followed by 6 states with 3%, i.e. Wyoming, South Dakota, Nebraska, Wisconsin, Mississippi and Iowa;
# - There are 5 states now with the highest partipcation rate of 100%, i.e. Colorado, Connecticut, Delaware, Michigan and Idaho.

# %%
# To identify states with the lowest participation rates for SAT in 2019
act_sat_all.sort_values('sat_participation_2019')[['state','sat_participation_2019']].head(20)
# Out:
#            state  sat_participation_2019
# 34  North Dakota                    0.02
# 50       Wyoming                    0.03
# 41  South Dakota                    0.03
# 27      Nebraska                    0.03
# 49     Wisconsin                    0.03
# 24   Mississippi                    0.03
# 15          Iowa                    0.03
# 44          Utah                    0.04
# 23     Minnesota                    0.04
# 17      Kentucky                    0.04
# 16        Kansas                    0.04
# 25      Missouri                    0.04
# 18     Louisiana                    0.05
# 3       Arkansas                    0.06
# 0        Alabama                    0.07
# 42     Tennessee                    0.07
# 26       Montana                    0.09
# 31    New Mexico                    0.18
# 35          Ohio                    0.19
# 28        Nevada                    0.20

# %%
# To identify states with the highest participation rates for SAT in 2019
act_sat_all.sort_values('sat_participation_2019',ascending=False)[['state','sat_participation_2019']].head(13)
# Out:
#                    state  sat_participation_2019
# 39          Rhode Island                    1.00
# 13              Illinois                    1.00
# 22              Michigan                    1.00
# 5               Colorado                    1.00
# 6            Connecticut                    1.00
# 7               Delaware                    1.00
# 9                Florida                    1.00
# 12                 Idaho                    1.00
# 19                 Maine                    0.99
# 48         West Virginia                    0.99
# 29         New Hampshire                    0.95
# 8   District of Columbia                    0.94
# 30            New Jersey                    0.82

# %% [markdown]
# Observations for SAT in 2019:
# - North Dakota remains to have the lowest participation rate at 2%, followed by 6 states with 3%, i.e. Wyoming, South Dakota, Nebraska, Wisconsin, Mississippi and Iowa;
# - There are 8 states now with the highest partipcation rate of 100%, i.e. Rhode Island, Illinois, Michigan, Colorado, Connecticut, Delaware, Florida and Idaho.

# %% [markdown]
# **Observations for Participation rates for ACT and SAT in 2017, 2018 and 2019:**
# - Firstly, when comparing the minimum (i.e. lowest) participation rate between ACT and SAT, ACT seems to have a higher minimum participation rate across the country.
#     - For instance, 6-8% minimum participation rate is observed for ACT, compared to 2% of that for SAT.
#     - This also indicates a striking difference from the 13-16 states with less than 6% participation rate for SAT.
#     - While SAT may be seen as "unnecessary" in some states, ACT seems to have a standard following across the country.
#         - This could be due to the fact that students who are keen to demonstrate their proficiency in Science, will participate in ACT *(since Science is not offered in SAT)*.
#
#
# - Secondly, with 15-17 states having 100% participation rates for ACT, but just 4-8 states for SAT, it is possible that the popularity of ACT is outpacing that of SAT.
#
#
# - Thirdly, there seems to be a trend whereby states with higher participation rate in one test, tends to have lower participation rate in the other. For example:
#     - Rhode Island has the second lowest participation rate for ACT in 2019 (at 12%), but has one of the highest participation rate for SAT in the same year (at 100%).
#     - Wyoming, Nebraska, Wisconsin and Mississippi have the second lowest participation rate for SAT in 2019 (at 3%), but emerge to have the highest participation rates for ACT in the same year (100%).

# %% [markdown]
# #### (2) Which states have the highest and lowest mean composite/total scores for ACT and SAT, across 2017, 2018 and 2019?

# %% [markdown]
# - To identify states with the highest mean score, we will consider the top 25th percentile (i.e. top 13).
# - To identify states with the lowest mean score, we will consider the bottom 25th percentile (i.e. bottom 13).

# %% [markdown]
# **Mean Composite Scores for ACT in 2017, 2018 and 2019**

# %%
# To identify states with the lowest mean composite score for ACT in 2017
act_sat_all.sort_values('act_composite_2017')[['state','act_composite_2017','act_participation_2017']].head(13)
# Out:
#              state  act_composite_2017  act_participation_2017
# 28          Nevada                17.8                    1.00
# 24     Mississippi                18.6                    1.00
# 40  South Carolina                18.7                    1.00
# 11          Hawaii                19.0                    0.90
# 33  North Carolina                19.1                    1.00
# 0          Alabama                19.2                    1.00
# 3         Arkansas                19.4                    1.00
# 36        Oklahoma                19.4                    1.00
# 18       Louisiana                19.5                    1.00
# 2          Arizona                19.7                    0.62
# 31      New Mexico                19.7                    0.66
# 1           Alaska                19.8                    0.65
# 42       Tennessee                19.8                    1.00

# %%
# To identify states with the highest mean composite score for ACT in 2017
act_sat_all.sort_values('act_composite_2017',ascending=False)[['state','act_composite_2017','act_participation_2017']].head(13)
# Out:
#                    state  act_composite_2017  act_participation_2017
# 29         New Hampshire                25.5                    0.18
# 21         Massachusetts                25.4                    0.29
# 6            Connecticut                25.2                    0.31
# 19                 Maine                24.3                    0.08
# 8   District of Columbia                24.2                    0.32
# 32              New York                24.2                    0.31
# 22              Michigan                24.1                    0.29
# 7               Delaware                24.1                    0.18
# 39          Rhode Island                24.0                    0.21
# 30            New Jersey                23.9                    0.34
# 46              Virginia                23.8                    0.29
# 38          Pennsylvania                23.7                    0.23
# 20              Maryland                23.6                    0.28

# %% [markdown]
# Observations for ACT in 2017:
# - Nevada has the lowest mean composite score of 17.8, whereas New Hampshire has the highest score of 25.5;
# - States with the lowest mean composite scores in ACT, are among the states with the highest participation rates (100%) in ACT.
#     - For instance, Nevada, Mississippi, South Carolina, North Carolina, Alabama, Arkansas, Oklahoma, Louisiana, Tennessee.
# - On the other hand, states with the highest mean composite scores in ACT, have one of the lowest participation rates in ACT.
#     - For instance, Maine (8%), New Hampshire (18%), Delaware (18%).

# %%
# To identify states with the lowest mean composite score for ACT in 2018
act_sat_all.sort_values('act_composite_2018')[['state','act_composite_2018','act_participation_2018']].head(13)
# Out:
#              state  act_composite_2018  act_participation_2018
# 28          Nevada                17.7                    1.00
# 40  South Carolina                18.3                    1.00
# 24     Mississippi                18.6                    1.00
# 11          Hawaii                18.9                    0.89
# 0          Alabama                19.1                    1.00
# 33  North Carolina                19.1                    1.00
# 2          Arizona                19.2                    0.66
# 18       Louisiana                19.2                    1.00
# 36        Oklahoma                19.3                    1.00
# 3         Arkansas                19.4                    1.00
# 31      New Mexico                19.4                    0.67
# 42       Tennessee                19.6                    1.00
# 9          Florida                19.9                    0.66

# %%
# To identify states with the highest mean composite score for ACT in 2018
act_sat_all.sort_values('act_composite_2018',ascending=False)[['state','act_composite_2018','act_participation_2018']].head(13)
# Out:
#             state  act_composite_2018  act_participation_2018
# 6     Connecticut                25.6                    0.26
# 21  Massachusetts                25.5                    0.25
# 29  New Hampshire                25.1                    0.16
# 32       New York                24.5                    0.27
# 22       Michigan                24.2                    0.22
# 39   Rhode Island                24.2                    0.15
# 45        Vermont                24.1                    0.24
# 19          Maine                24.0                    0.07
# 13       Illinois                23.9                    0.43
# 5        Colorado                23.9                    0.30
# 46       Virginia                23.9                    0.24
# 7        Delaware                23.8                    0.17
# 30     New Jersey                23.7                    0.31

# %% [markdown]
# Observations for ACT in 2018:
# - Nevada has the lowest mean composite score of 17.7 once again, whereas Connecticut has the highest score of 25.6;
# - A similar trend as those in 2017 is observed for 2018, where:
#     - States with the lowest mean composite scores in ACT, are among the states with the highest participation rates (100%) in ACT.
#         - For instance, Nevada, South Carolina, Mississippi, Alabama, North Carolina, Louisiana, Oklahoma, Arkansas, Tennessee.
# - On the other hand, states with the highest mean composite scores in ACT, have one of the lowest participation rates in ACT.
#     - For instance, Maine (7%), New Hampshire (16%).

# %%
# To identify states with the lowest mean composite score for ACT in 2019
act_sat_all.sort_values('act_composite_2019')[['state','act_composite_2019','act_participation_2019']].head(13)
# Out:
#              state  act_composite_2019  act_participation_2019
# 28          Nevada                17.9                    1.00
# 24     Mississippi                18.4                    1.00
# 40  South Carolina                18.8                    0.78
# 18       Louisiana                18.8                    1.00
# 0          Alabama                18.9                    1.00
# 36        Oklahoma                18.9                    1.00
# 2          Arizona                19.0                    0.73
# 33  North Carolina                19.0                    1.00
# 11          Hawaii                19.0                    0.80
# 3         Arkansas                19.3                    1.00
# 31      New Mexico                19.3                    0.63
# 42       Tennessee                19.4                    1.00
# 26         Montana                19.8                    1.00

# %%
# To identify states with the highest mean composite score for ACT in 2019
act_sat_all.sort_values('act_composite_2019',ascending=False)[['state','act_composite_2019','act_participation_2019']].head(13)
# Out:
#             state  act_composite_2019  act_participation_2019
# 21  Massachusetts                25.5                    0.21
# 6     Connecticut                25.5                    0.22
# 29  New Hampshire                25.0                    0.14
# 39   Rhode Island                24.7                    0.12
# 32       New York                24.5                    0.22
# 22       Michigan                24.4                    0.19
# 19          Maine                24.3                    0.06
# 13       Illinois                24.3                    0.35
# 30     New Jersey                24.2                    0.25
# 45        Vermont                24.1                    0.20
# 7        Delaware                24.1                    0.13
# 46       Virginia                24.0                    0.21
# 5        Colorado                23.8                    0.27

# %% [markdown]
# Observations for ACT in 2019:
# - Nevada has the lowest mean composite score of 17.9 once again, whereas Massachusetts has the highest score of 25.5;
# - A similar trend as those in 2017 and 2018 is observed for 2019 again, where:
#     - States with the lowest mean composite scores in ACT, are among the states with the highest participation rates (100%) in ACT.
#         - For instance, Nevada, Mississippi, Louisiana, Alabama, Oklahoma, North Carolina, Arkansas, Tennessee, Montana.
# - On the other hand, states with the highest mean composite scores in ACT, have one of the lowest participation rates in ACT.
#     - For instance, Maine (6%), Rhode Island (12%).

# %% [markdown]
# **Mean Total Scores for SAT in 2017, 2018 and 2019**

# %%
# To identify states with the lowest mean total score for SAT in 2017
act_sat_all.sort_values('sat_total_2017')[['state','sat_total_2017','sat_participation_2017']].head(13)
# Out:
#                    state  sat_total_2017  sat_participation_2017
# 8   District of Columbia             950                    1.00
# 7               Delaware             996                    1.00
# 12                 Idaho            1005                    0.93
# 22              Michigan            1005                    1.00
# 19                 Maine            1012                    0.95
# 9                Florida            1017                    0.83
# 43                 Texas            1020                    0.62
# 6            Connecticut            1041                    1.00
# 36              Oklahoma            1047                    0.07
# 10               Georgia            1050                    0.61
# 32              New York            1052                    0.67
# 29         New Hampshire            1052                    0.96
# 4             California            1055                    0.53

# %%
# To identify states with the highest mean total score for SAT in 2017
act_sat_all.sort_values('sat_total_2017',ascending=False)[['state','sat_total_2017','sat_participation_2017']].head(13)
# Out:
#            state  sat_total_2017  sat_participation_2017
# 23     Minnesota            1295                    0.03
# 49     Wisconsin            1291                    0.03
# 15          Iowa            1275                    0.02
# 25      Missouri            1271                    0.03
# 16        Kansas            1260                    0.04
# 34  North Dakota            1256                    0.02
# 27      Nebraska            1253                    0.03
# 17      Kentucky            1247                    0.04
# 24   Mississippi            1242                    0.02
# 44          Utah            1238                    0.03
# 50       Wyoming            1230                    0.03
# 42     Tennessee            1228                    0.05
# 41  South Dakota            1216                    0.03

# %% [markdown]
# Observations for SAT in 2017:
# - District of Columbia has the lowest mean total score of 950, whereas Minnesota has the highest score of 1295;
# - States with the lowest mean total scores in SAT, are among the states with the highest participation rates (100%) in SAT.
#     - For instance, District of Columbia, Delaware, Michigan, Connecticut.
# - On the other hand, states with the highest mean total scores in SAT, have one of the lowest participation rates (2%) in SAT.
#     - For instance, Iowa, North Dakota, Mississippi.

# %%
# To identify states with the lowest mean total score for SAT in 2018
act_sat_all.sort_values('sat_total_2018')[['state','sat_total_2018','sat_participation_2018']].head(13)
# Out:
#                    state  sat_total_2018  sat_participation_2018
# 8   District of Columbia             977                    0.92
# 7               Delaware             998                    1.00
# 48         West Virginia             999                    0.28
# 12                 Idaho            1001                    1.00
# 44                  Utah            1010                    0.04
# 11                Hawaii            1010                    0.56
# 22              Michigan            1011                    1.00
# 19                 Maine            1013                    0.99
# 39          Rhode Island            1018                    0.97
# 13              Illinois            1019                    0.99
# 5               Colorado            1025                    1.00
# 43                 Texas            1032                    0.66
# 6            Connecticut            1053                    1.00

# %%
# To identify states with the highest mean total score for SAT in 2018
act_sat_all.sort_values('sat_total_2018',ascending=False)[['state','sat_total_2018','sat_participation_2018']].head(13)
# Out:
#            state  sat_total_2018  sat_participation_2018
# 23     Minnesota            1298                    0.04
# 49     Wisconsin            1294                    0.03
# 34  North Dakota            1283                    0.02
# 15          Iowa            1265                    0.03
# 16        Kansas            1265                    0.04
# 25      Missouri            1262                    0.04
# 50       Wyoming            1257                    0.03
# 27      Nebraska            1252                    0.03
# 17      Kentucky            1248                    0.04
# 41  South Dakota            1240                    0.03
# 24   Mississippi            1236                    0.03
# 42     Tennessee            1231                    0.06
# 18     Louisiana            1210                    0.04

# %% [markdown]
# Observations for SAT in 2018:
# - District of Columbia has the lowest mean total score of 977, whereas Minnesota has the highest score of 1298;
# - States with the lowest mean total scores in SAT, are among the states with the highest participation rates (100%) in SAT.
#     - For instance, Delaware, Idaho, Michigan, Colorado, Connecticut.
#     - An exception will be West Virginia and Utah, which have low scores despite low participation rates of 28% and 4% respectively. This is a cause for concern.
# - On the other hand, states with the highest mean total scores in SAT, have one of the lowest participation rates (2-3%) in SAT.
#     - For instance, North Dakota, Wisconsin, Iowa, Wyoming, Nebraska, South Dakota, Mississippi.

# %%
# To identify states with the lowest mean total score for SAT in 2019
act_sat_all.sort_values('sat_total_2019')[['state','sat_total_2019','sat_participation_2019']].head(13)
# Out:
#                    state  sat_total_2019  sat_participation_2019
# 48         West Virginia             943                    0.99
# 36              Oklahoma             963                    0.22
# 8   District of Columbia             975                    0.94
# 7               Delaware             985                    1.00
# 12                 Idaho             993                    1.00
# 39          Rhode Island             995                    1.00
# 9                Florida             999                    1.00
# 22              Michigan            1003                    1.00
# 19                 Maine            1013                    0.99
# 13              Illinois            1013                    1.00
# 43                 Texas            1022                    0.68
# 5               Colorado            1024                    1.00
# 40        South Carolina            1030                    0.68

# %%
# To identify states with the highest mean total score for SAT in 2017
act_sat_all.sort_values('sat_total_2019',ascending=False)[['state','sat_total_2019','sat_participation_2019']].head(13)
# Out:
#            state  sat_total_2019  sat_participation_2019
# 23     Minnesota            1284                    0.04
# 49     Wisconsin            1283                    0.03
# 41  South Dakota            1268                    0.03
# 34  North Dakota            1263                    0.02
# 27      Nebraska            1260                    0.03
# 15          Iowa            1244                    0.03
# 16        Kansas            1241                    0.04
# 50       Wyoming            1238                    0.03
# 24   Mississippi            1237                    0.03
# 25      Missouri            1236                    0.04
# 17      Kentucky            1232                    0.04
# 44          Utah            1230                    0.04
# 42     Tennessee            1220                    0.07

# %% [markdown]
# Observations for SAT in 2019:
# - West Virginia has the lowest mean total score of 943, whereas Minnesota has the highest score of 1284;
# - States with the lowest mean total scores in SAT, are among the states with the highest participation rates (100%) in SAT.
#     - For instance, Delaware, Idaho, Rhode Island, Florida, Michigan, Illinois, Colorado.
#     - An exception will be Oklahoma, which has a low score of 963 despite low participation rate of 22%. This is a cause for concern.
# - On the other hand, states with the highest mean total scores in SAT, have one of the lowest participation rates (2-3%) in SAT.
#     - For instance, North Dakota, Wisconsin, South Dakota, Nebraska, Iowa, Wyoming, Mississippi.

# %% [markdown]
# **Observations for mean Composite/Total Scores for ACT and SAT in 2017, 2018 and 2019:**
# - Firstly, when comparing the highest and lowest mean composite/total scores for ACT and SAT, states tend to occupy the same positions from year to year.
#
#
# - Secondly, there seems to be a trend whereby states with higher score in one test, tends to have lower scores in the other, though this trend is not as obvious compared to participation rates. For example:
#     - Mississippi and Tennessee have one of the highest mean total scores for SAT in 2019 (1237 and 1220 respectively), but one the lowest mean composite scores for ACT in 2019 (18.4 and 19.4 respectively).
#     - Rhode Island, Michigan, Maine and Illinois have one of the highest mean composite scores for ACT in 2019 (24.7, 24.4, 24.3 and 24.3 respectively), but one of the lowest mean total scores for SAT in 2019 (995, 1003, 1013 and 1013 respectively).
#
#
# - Thirdly, states with the lowest mean total scores in SAT, are among the states with the highest participation rates (100%) in SAT, whereas states with the highest mean total scores in SAT tend to have the lowest participation rates in SAT. The same effect is also observed in ACT.
#     - This inherently represents a selection bias, where students who participate in SAT and/or ACT tend to be higher-achieving students who may be pursuing college applications outside of their states or prestigious college courses, and therefore require more test results to boost their chances of being accepted into those colleges.
#     - What this also means is that having higher mean composite/total scores may not necessarily indicate that the states have better education systems.
#     - An exception will be Oklahoma, which has a low score of 963 despite low participation rate of 22% in SAT in 2019.

# %% [markdown]
# #### (3) Do any states with 100% participation on a given test have a rate change year-to-year?

# %% [markdown]
# **Participation rate change in ACT for states with 100% participation in 2017, 2018 and/or 2019**

# %%
# To compute the change in participation rates for ACT in 2017, 2018 and 2019
act_sat_all['act_participation_change_2017_2018'] = act_sat_all['act_participation_2018'] - act_sat_all['act_participation_2017']
act_sat_all['act_participation_change_2018_2019'] = act_sat_all['act_participation_2019'] - act_sat_all['act_participation_2018']

# %%
# To identify states with 100% participation rate for ACT in 2017, 2018 and/or 2019, against the change in participation rates 
act_sat_all[(act_sat_all['act_participation_2017'] == 1.00) | (act_sat_all['act_participation_2018'] == 1.00) | (act_sat_all['act_participation_2019'] == 1.00)][['state','act_participation_2017','act_participation_2018','act_participation_2019','act_participation_change_2017_2018','act_participation_change_2018_2019']]
# Out:
#              state  act_participation_2017  act_participation_2018  \
# 0          Alabama                    1.00                    1.00
# 3         Arkansas                    1.00                    1.00
# 5         Colorado                    1.00                    0.30
# 17        Kentucky                    1.00                    1.00
# 18       Louisiana                    1.00                    1.00
# 23       Minnesota                    1.00                    0.99
# 24     Mississippi                    1.00                    1.00
# 25        Missouri                    1.00                    1.00
# 26         Montana                    1.00                    1.00
# 27        Nebraska                    0.84                    1.00
# 28          Nevada                    1.00                    1.00
# 33  North Carolina                    1.00                    1.00
# 35            Ohio                    0.75                    1.00
# ...

# %% [markdown]
# Observations for ACT in 2017, 2018 and/or 2019:
# - There are 17 states with 100% participation rates in ACT in 2017, 17 states in 2018, and 15 states in 2019.
#
#
# - Between 2017 and 2018, these states do not have changes in participation rates, except for the following:
#     - Drop in participation rates:
#         - Colorado: -70%
#         - Minnesota: -1%
#     - Rise in participation rates:
#         - Nebraska: +16%
#         - Ohio: +25%
#
#
# - Between 2018 and 2019, these states do not have changes in participation rates, except for the following:
#     - Drop in participation rates:
#         - Colorado: -3%
#         - Minnesota: -4%
#         - Missouri: -18%
#         - South Carolina: -22%
#
#
# - The drop in participation rates is likely due to ACT being removed as a mandatory assessment in the state (i.e. South Carolina where students can choose to participate in either SAT or ACT, thus students may switch over to SAT), whereas the rise in participation rates is liekly due to ACT being made a mandatory requirement for all students (i.e. Nebraska where students are required to take ACT with Writing).

# %% [markdown]
# **Participation rate change in SAT for states with 100% participation in 2017, 2018 and/or 2019**

# %%
# To compute the change in participation rates for SAT in 2017, 2018 and 2019
act_sat_all['sat_participation_change_2017_2018'] = act_sat_all['sat_participation_2018'] - act_sat_all['sat_participation_2017']
act_sat_all['sat_participation_change_2018_2019'] = act_sat_all['sat_participation_2019'] - act_sat_all['sat_participation_2018']

# %%
# To identify states with 100% participation rate for SAT in 2017, 2018 and/or 2019, against the change in participation rates
act_sat_all[(act_sat_all['sat_participation_2017'] == 1.00) | (act_sat_all['sat_participation_2018'] == 1.00) | (act_sat_all['sat_participation_2019'] == 1.00)][['state','sat_participation_2017','sat_participation_2018','sat_participation_2019','sat_participation_change_2017_2018','sat_participation_change_2018_2019']]
# Out:
#                    state  sat_participation_2017  sat_participation_2018  \
# 5               Colorado                    0.11                    1.00
# 6            Connecticut                    1.00                    1.00
# 7               Delaware                    1.00                    1.00
# 8   District of Columbia                    1.00                    0.92
# 9                Florida                    0.83                    0.56
# 12                 Idaho                    0.93                    1.00
# 13              Illinois                    0.09                    0.99
# 22              Michigan                    1.00                    1.00
# 39          Rhode Island                    0.71                    0.97
#
#     sat_participation_2019  sat_participation_change_2017_2018  \
# 5                     1.00                                0.89
# 6                     1.00                                0.00
# ...

# %% [markdown]
# Observations for SAT in 2017, 2018 and/or 2019:
# - There are 4 states with 100% participation rates in SAT in 2017, 5 states in 2018, and 8 states in 2019.
#
#
# - Between 2017 and 2018, these states do not have changes in participation rates, except for the following:
#     - Drop in participation rates:
#         - District of Columbia: -8%
#         - Florida: -27%
#     - Rise in participation rates:
#         - Colorado: +89%
#         - Idaho: +7%
#         - Illinois: +90%
#         - Rhode Island: +26%
#
#
# - Between 2018 and 2019, these states do not have changes in participation rates, except for the following:
#     - Rise in participation rates:
#         - District of Columbia: +2%
#         - Florida: +44%
#         - Illinois: +1%
#         - Rhode Island: +3%
#
#
# - The drop in participation rates is likely due to SAT being removed as a mandatory assessment in the state (i.e. Florida where students can choose to participate in either SAT or ACT, thus students may choose ACT instead), whereas the rise in participation rates is likely due to SAT being made a mandatory requirement for all students (i.e. Colorado and Illinois where juniors are required to take SAT).

# %% [markdown]
# #### (4) Do any states have >50% participation on both tests each year?

# %% [markdown]
# **Participation rates for ACT and SAT in 2017**

# %%
# To identify states with >50% participation rates on both ACT and SAT in 2017
act_sat_all[(act_sat_all['act_participation_2017'] > 0.5) & (act_sat_all['sat_participation_2017'] > 0.5)][['state','act_participation_2017','sat_participation_2017']]
# Out:
#       state  act_participation_2017  sat_participation_2017
# 9   Florida                    0.73                    0.83
# 10  Georgia                    0.55                    0.61
# 11   Hawaii                    0.90                    0.55

# %% [markdown]
# States with >50% participation rates on both ACT and SAT in 2017 include Florida, Georgia and Hawaii.

# %% [markdown]
# **Participation rates for ACT and SAT in 2018**

# %%
# To identify states with >50% participation rates on both ACT and SAT in 2018
act_sat_all[(act_sat_all['act_participation_2018'] > 0.5) & (act_sat_all['sat_participation_2018'] > 0.5)][['state','act_participation_2018','sat_participation_2018']]
# Out:
#              state  act_participation_2018  sat_participation_2018
# 9          Florida                    0.66                    0.56
# 10         Georgia                    0.53                    0.70
# 11          Hawaii                    0.89                    0.56
# 33  North Carolina                    1.00                    0.52
# 40  South Carolina                    1.00                    0.55

# %% [markdown]
# States with >50% participation rates on both ACT and SAT in 2018 include Florida, Georgia, Hawaii, North Carolina and South Carolina.

# %% [markdown]
# **Participation rates for ACT and SAT in 2019**

# %%
# To identify states with >50% participation rates on both ACT and SAT in 2019
act_sat_all[(act_sat_all['act_participation_2019'] > 0.5) & (act_sat_all['sat_participation_2019'] > 0.5)][['state','act_participation_2019','sat_participation_2019']]
# Out:
#              state  act_participation_2019  sat_participation_2019
# 9          Florida                    0.54                    1.00
# 11          Hawaii                    0.80                    0.54
# 33  North Carolina                    1.00                    0.51
# 40  South Carolina                    0.78                    0.68

# %% [markdown]
# States with >50% participation rates on both ACT and SAT in 2019 include Florida, Hawaii, North Carolina and South Carolina.

# %% [markdown]
# #### (5) Do any states have 100% participation on either ACT or SAT across 2017, 2018 and 2019?

# %% [markdown]
# **Participation rates for ACT in 2017, 2018 and 2019**

# %%
# To identify states with 100% participation rates in ACT from 2017 to 2019
act_sat_all[(act_sat_all['act_participation_2017'] == 1.00) & (act_sat_all['act_participation_2018'] == 1.00) & (act_sat_all['act_participation_2019'] == 1.00)][['state','act_participation_2017','act_participation_2018','act_participation_2019']]
# Out:
#              state  act_participation_2017  act_participation_2018  \
# 0          Alabama                     1.0                     1.0
# 3         Arkansas                     1.0                     1.0
# 17        Kentucky                     1.0                     1.0
# 18       Louisiana                     1.0                     1.0
# 24     Mississippi                     1.0                     1.0
# 26         Montana                     1.0                     1.0
# 28          Nevada                     1.0                     1.0
# 33  North Carolina                     1.0                     1.0
# 36        Oklahoma                     1.0                     1.0
# 42       Tennessee                     1.0                     1.0
# 44            Utah                     1.0                     1.0
# 49       Wisconsin                     1.0                     1.0
# 50         Wyoming                     1.0                     1.0
#
#     act_participation_2019
# ...

# %% [markdown]
# States with 100% participation on ACT across 2017, 2018 and 2019 include Alabama, Arkansas, Kentucky, Louisiana, Mississippi, Montana, Nevada, North Carolina, Oklahoma, Tennessee, Utah, Wisconsin, Wyoming.

# %% [markdown]
# **Participation rates for SAT in 2017, 2018 and 2019**

# %%
# To identify states with 100% participation rates in SAT from 2017 to 2019
act_sat_all[(act_sat_all['sat_participation_2017'] == 1.00) & (act_sat_all['sat_participation_2018'] == 1.00) & (act_sat_all['sat_participation_2019'] == 1.00)][['state','sat_participation_2017','sat_participation_2018','sat_participation_2019']]
# Out:
#           state  sat_participation_2017  sat_participation_2018  \
# 6   Connecticut                     1.0                     1.0
# 7      Delaware                     1.0                     1.0
# 22     Michigan                     1.0                     1.0
#
#     sat_participation_2019
# 6                      1.0
# 7                      1.0
# 22                     1.0

# %% [markdown]
# States with 100% participation on SAT across 2017, 2018 and 2019 include Connecticut, Delaware, Michigan.

# %% [markdown]
# #### (6) Which states have the most significant change in participation rates on either ACT or SAT each year?

# %% [markdown]
# **Change in participation rates for ACT across 2017 to 2019**

# %%
# To identify states with significant positive changes in participation rate for ACT from 2017 to 2018
act_sat_all.sort_values('act_participation_change_2017_2018', ascending=False)[['state','act_participation_2017','act_participation_2018','act_participation_change_2017_2018']].head(10)
# Out:
#              state  act_participation_2017  act_participation_2018  \
# 35            Ohio                    0.75                    1.00
# 27        Nebraska                    0.84                    1.00
# 2          Arizona                    0.62                    0.66
# 20        Maryland                    0.28                    0.31
# 37          Oregon                    0.40                    0.42
# 15            Iowa                    0.67                    0.68
# 31      New Mexico                    0.66                    0.67
# 0          Alabama                    1.00                    1.00
# 33  North Carolina                    1.00                    1.00
# 26         Montana                    1.00                    1.00
#
#     act_participation_change_2017_2018
# 35                                0.25
# 27                                0.16
# 2                                 0.04
# 20                                0.03
# ...

# %%
# To identify states with significant negative changes in participation rate for ACT from 2017 to 2018
act_sat_all.sort_values('act_participation_change_2017_2018')[['state','act_participation_2017','act_participation_2018','act_participation_change_2017_2018']].head(10)
# Out:
#            state  act_participation_2017  act_participation_2018  \
# 5       Colorado                    1.00                    0.30
# 13      Illinois                    0.93                    0.43
# 1         Alaska                    0.65                    0.33
# 22      Michigan                    0.29                    0.22
# 9        Florida                    0.73                    0.66
# 39  Rhode Island                    0.21                    0.15
# 46      Virginia                    0.29                    0.24
# 45       Vermont                    0.29                    0.24
# 47    Washington                    0.29                    0.24
# 6    Connecticut                    0.31                    0.26
#
#     act_participation_change_2017_2018
# 5                                -0.70
# 13                               -0.50
# 1                                -0.32
# 22                               -0.07
# 9                                -0.07
# ...

# %%
# To identify states with significant positive changes in participation rate for ACT from 2018 to 2019
act_sat_all.sort_values('act_participation_change_2018_2019', ascending=False)[['state','act_participation_2018','act_participation_2019','act_participation_change_2018_2019']].head(10)
# Out:
#              state  act_participation_2018  act_participation_2019  \
# 2          Arizona                    0.66                    0.73
# 1           Alaska                    0.33                    0.38
# 16          Kansas                    0.71                    0.72
# 35            Ohio                    1.00                    1.00
# 24     Mississippi                    1.00                    1.00
# 26         Montana                    1.00                    1.00
# 27        Nebraska                    1.00                    1.00
# 28          Nevada                    1.00                    1.00
# 33  North Carolina                    1.00                    1.00
# 0          Alabama                    1.00                    1.00
#
#     act_participation_change_2018_2019
# 2                                 0.07
# 1                                 0.05
# 16                                0.01
# 35                                0.00
# ...

# %%
# To identify states with significant negative changes in participation rate for ACT from 2018 to 2019
act_sat_all.sort_values('act_participation_change_2018_2019')[['state','act_participation_2018','act_participation_2019','act_participation_change_2018_2019']].head(10)
# Out:
#              state  act_participation_2018  act_participation_2019  \
# 40  South Carolina                    1.00                    0.78
# 25        Missouri                    1.00                    0.82
# 48   West Virginia                    0.65                    0.49
# 9          Florida                    0.66                    0.54
# 11          Hawaii                    0.89                    0.80
# 13        Illinois                    0.43                    0.35
# 30      New Jersey                    0.31                    0.25
# 43           Texas                    0.45                    0.39
# 32        New York                    0.27                    0.22
# 12           Idaho                    0.36                    0.31
#
#     act_participation_change_2018_2019
# 40                               -0.22
# 25                               -0.18
# 48                               -0.16
# 9                                -0.12
# ...

# %% [markdown]
# States with most significant positive changes in participation rates for ACT (>10%) include:
# - From 2017 to 2018: Ohio (+25%), Nebraska (+16%), Arizona (+4%)
# - From 2018 to 2019: -
#
# States with most significant negative changes in participation rates for ACT (less than -10%) include:
# - From 2017 to 2018: Colorado (-70%), Illinois (-50%), Alaska (-32%)
# - From 2018 to 2019: South Carolina (-22%), Missouri (-18%), West Virginia (-16%), Florida (-12%)
#
# These states provide hints as to where there is an increasing participation in ACT, and therefore increasing demand for ACT tuition services.

# %% [markdown]
# **Change in participation rates for SAT across 2017 to 2019**

# %%
# To identify states with significant positive changes in participation rate for SAT from 2017 to 2018
act_sat_all.sort_values('sat_participation_change_2017_2018', ascending=False)[['state','sat_participation_2017','sat_participation_2018','sat_participation_change_2017_2018']].head(10)
# Out:
#             state  sat_participation_2017  sat_participation_2018  \
# 13       Illinois                    0.09                    0.99
# 5        Colorado                    0.11                    1.00
# 39   Rhode Island                    0.71                    0.97
# 48  West Virginia                    0.14                    0.28
# 30     New Jersey                    0.70                    0.82
# 32       New York                    0.67                    0.79
# 10        Georgia                    0.61                    0.70
# 20       Maryland                    0.69                    0.76
# 12          Idaho                    0.93                    1.00
# 4      California                    0.53                    0.60
#
#     sat_participation_change_2017_2018
# 13                                0.90
# 5                                 0.89
# 39                                0.26
# 48                                0.14
# 30                                0.12
# ...

# %%
# To identify states with significant negative changes in participation rate for SAT from 2017 to 2018
act_sat_all.sort_values('sat_participation_change_2017_2018')[['state','sat_participation_2017','sat_participation_2018','sat_participation_change_2017_2018']].head(10)
# Out:
#                    state  sat_participation_2017  sat_participation_2018  \
# 9                Florida                    0.83                    0.56
# 8   District of Columbia                    1.00                    0.92
# 28                Nevada                    0.26                    0.23
# 2                Arizona                    0.30                    0.29
# 17              Kentucky                    0.04                    0.04
# 16                Kansas                    0.04                    0.04
# 49             Wisconsin                    0.03                    0.03
# 14               Indiana                    0.63                    0.63
# 26               Montana                    0.10                    0.10
# 27              Nebraska                    0.03                    0.03
#
#     sat_participation_change_2017_2018
# 9                                -0.27
# 8                                -0.08
# 28                               -0.03
# ...

# %%
# To identify states with significant positive changes in participation rate for SAT from 2018 to 2019
act_sat_all.sort_values('sat_participation_change_2018_2019', ascending=False)[['state','sat_participation_2018','sat_participation_2019','sat_participation_change_2018_2019']].head(10)
# Out:
#              state  sat_participation_2018  sat_participation_2019  \
# 48   West Virginia                    0.28                    0.99
# 9          Florida                    0.56                    1.00
# 36        Oklahoma                    0.08                    0.22
# 40  South Carolina                    0.55                    0.68
# 20        Maryland                    0.76                    0.82
# 39    Rhode Island                    0.97                    1.00
# 37          Oregon                    0.48                    0.51
# 4       California                    0.60                    0.63
# 14         Indiana                    0.63                    0.66
# 43           Texas                    0.66                    0.68
#
#     sat_participation_change_2018_2019
# 48                                0.71
# 9                                 0.44
# 36                                0.14
# 40                                0.13
# ...

# %%
# To identify states with significant negative changes in participation rate for SAT from 2018 to 2019
act_sat_all.sort_values('sat_participation_change_2018_2019')[['state','sat_participation_2018','sat_participation_2019','sat_participation_change_2018_2019']].head(10)
# Out:
#              state  sat_participation_2018  sat_participation_2019  \
# 28          Nevada                    0.23                    0.20
# 1           Alaska                    0.43                    0.41
# 11          Hawaii                    0.56                    0.54
# 26         Montana                    0.10                    0.09
# 33  North Carolina                    0.52                    0.51
# 29   New Hampshire                    0.96                    0.95
# 25        Missouri                    0.04                    0.04
# 24     Mississippi                    0.03                    0.03
# 49       Wisconsin                    0.03                    0.03
# 27        Nebraska                    0.03                    0.03
#
#     sat_participation_change_2018_2019
# 28                               -0.03
# 1                                -0.02
# 11                               -0.02
# 26                               -0.01
# ...

# %% [markdown]
# States with most significant positive changes in participation rates for SAT (>10%) include:
# - From 2017 to 2018: Illinois (+90%), Colorado (+89%), Rhode Island (+26%), West Virginia (+14%), New Jersey (+12%), New York (+12%)
# - From 2018 to 2019: West Virginia (+71%), Florida (+44%), Oklahoma (+14%), South Carolina (+13%)
#
# States with most significant negative changes in participation rates for SAT (less than -10%) include:
# - From 2017 to 2018: Florida (-27%)
# - From 2018 to 2019: -
#
# These states provide hints as to where there is an increasing participation in SAT, and therefore increasing demand for SAT tuition services.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ### 1. Correlation Heatmap

# %%
# To create a heatmap that visualizes the correlation between all numeric features 
fig = plt.figure(figsize=(15,15))
heatmap_all = sns.heatmap(act_sat_all.corr(),annot=True)
heatmap_all.set_title('Correlation Heatmap for ACT and SAT');

# %% [markdown]
# Observations:
# - The correlation between ACT and SAT participation rates are highly negative (2017: -0.84, 2018: -0.87, 2019: -0.87).
#     - This indicates that states with higher ACT participation rates, tend to have lower SAT participation rates, and vice versa.
#     - It is worthwhile to note that states such as Florida, Hawaii, North Carolina and South Carolina, have >50% participation rates on both ACT and SAT in 2019.
#
#
# - The correlation between participation rates and scores for each tests is highly negative, as follows:
#     - Within ACT, 2017: -0.86, 2018: -0.86, 2019: -0.87
#     - Within SAT, 2017: -0.87, 2018: -0.79, 2019: -0.86
#     - This suggests that the higher the participation rate, the lower the mean scores, and vice versa.
#         - This is likely due to the fact that with higher participation rates, there will be a wider range of students with different skill sets and abilities taking up the tests, thus resulting in a lower mean scores; whereas for lower participation rates, only students who are highly motivated and likely to excel in their academics, will take up the tests, thus the selection bias allows for higher mean scores.
#
#
# - The participation rates for ACT are moderately positively correlated with the mean total scores on SAT, and vice versa, as follows:
#     - ACT participation rates vs SAT total scores, 2017: 0.70, 2018: 0.62, 2019: 0.67
#     - SAT participation rates vs ACT composite scores, 2017: 0.69, 2018: 0.76, 2019: 0.72
#     - This suggests that higher SAT participations are associated with higher mean composite scores for ACT; the reverse holds true.
#
#
# - The mean composite scores on ACT tend to be moderately negatively correlated with the mean total scores on SAT, as follows:
#     - 2017: -0.45, 2018: -0.41, 2019: -0.42
#     - This is likely the result of selection bias, where higher scores on SAT are associated with lower participation rates in SAT but higher participation rates in ACT, and therefore lower scores on ACT. The reverse holds true.
#     - However, it is worthwhile to note that in low achieving states such as Oklahoma, it has a low score of 963 for SAT in 2019 despite low participation rate of 22%.
#
#
# - The correlation between total scores and scores for individual subjects of the same test tend to be highly positive, i.e. ~0.85 for ACT in 2017, ~0.99 for SAT in 2018, etc.
#     - This indicates that states which perform well on the test (either SAT or ACT), tend to perform well on almost all sections in the same test.

# %% [markdown]
# ### 2. Histograms

# %%
# To create a function for histogram (subplot) to visualise the distributions 

def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels, figsize_tuple, bins_range=False):

    # to ensure that there are sufficient rows
    number_of_rows = int(np.ceil(len(list_of_columns)/2))
    
    # to specify figsize
    fig, ax = plt.subplots(figsize=figsize_tuple,nrows=number_of_rows, ncols=2) 
    
    # to turn a matrix into a vector 
    ax = ax.ravel()
    index = 0 
    
    # to provide an index value for all lists 
    for i, column in enumerate(list_of_columns):
        
        if 'act_' in column:
            color = 'seagreen'
        if 'sat_' in column:
            color = 'steelblue'

        ax[i].hist(dataframe[column], bins=bins_range, color=color)
        ax[i].set_title(list_of_titles[i]) 
        ax[i].set_xlabel(list_of_xlabels[i])
        ax[i].set_ylabel(list_of_ylabels[i])
        
        index += 1

# %% [markdown]
# #### (1) Comparing Participation rates for ACT and SAT from 2017 to 2019

# %% [markdown]
# **Participation rates for ACT and SAT in 2017**

# %%
# To plot a histogram to compare the participation rates for ACT and SAT in 2017
subplot_histograms(
    act_sat_all,
    ['act_participation_2017','sat_participation_2017'],
    ['ACT Participation in 2017','SAT Participation in 2017'],
    ['Participation Rate','Participation Rate'],
    ['Count of States','Count of States'],
    (12,5),
    [0.1*i for i in range(0,11)]          # included to have equal bins at the tenth percentile from 0 to 100
)

plt.show()

# %% [markdown]
# Observations:
# - ACT has:
#     - Close to zero states with lower than 10% participation;
#     - A cluster in the range of 20-40% participation;
#     - A smaller cluster in the range of 60-80% participation;
#     - A larger group of states near to 100% participation.
# - On the contrary, SAT has:
#     - A huge group of states with lower than 10% participation;
#     - A cluster of states in the mid-to-high range of 50-70% participation;
#     - A moderately smaller cluster of states near to 100% participation.
# - Both distributions for ACT and SAT almost mirror each other.

# %% [markdown]
# **Participation rates for ACT and SAT in 2018**

# %%
# To plot a histogram to compare the participation rates for ACT and SAT in 2018

subplot_histograms(
    act_sat_all,
    ['act_participation_2018','sat_participation_2018'],
    ['ACT Participation in 2018','SAT Participation in 2018'],
    ['Participation Rate','Participation Rate'],
    ['Count of States','Count of States'],
    (12,5),
    [0.1*i for i in range(0,11)]          # included to have equal bins at the tenth percentile from 0 to 100
)

plt.show()

# %% [markdown]
# Observations:
# - In 2018, the distributions for participation rates in ACT and SAT have not changed significantly, as compared to 2017.
# - There is a slight decrease in the number of states near to 100% participation for ACT, whereas a slight increase in the number of states near to 100% participation for SAT can be seen.

# %% [markdown]
# **Participation rates for ACT and SAT in 2019**

# %%
# To plot a histogram to compare the participation rates for ACT and SAT in 2019
subplot_histograms(
    act_sat_all,
    ['act_participation_2019','sat_participation_2019'],
    ['ACT Participation in 2019','SAT Participation in 2019'],
    ['Participation Rate','Participation Rate'],
    ['Count of States','Count of States'],
    (12,5),
    [0.1*i for i in range(0,11)]          # included to have equal bins at the tenth percentile from 0 to 100
)

plt.show()

# %% [markdown]
# Observations:
# - In 2019, the distributions for participation rates in ACT and SAT have yet to change significantly, as compared to 2018.
# - Though it can be observed that there is a slight decrease in the number of states near to 100% participation for ACT, and a slight increase in the number of states near to 100% participation for SAT.

# %% [markdown]
# #### (2) Comparing Composite/Total scores for ACT and SAT from 2017 to 2019

# %% [markdown]
# **Composite/Total scores for ACT and SAT in 2017**

# %%
# To plot a histogram to compare the composite/total scores for ACT and SAT in 2017
subplot_histograms(
    act_sat_all,
    ['act_composite_2017','sat_total_2017'],
    ['ACT Composite Score in 2017','SAT Total Score in 2017'],
    ['Composite Score','Total Score'],
    ['Count of States','Count of States'],
    (12,5),
    10
)

plt.show()

# %% [markdown]
# **Composite/Total scores for ACT and SAT in 2018**

# %%
# To plot a histogram to compare the composite/total scores for ACT and SAT in 2018
subplot_histograms(
    act_sat_all,
    ['act_composite_2018','sat_total_2018'],
    ['ACT Composite Score in 2018','SAT Total Score in 2018'],
    ['Composite Score','Total Score'],
    ['Count of States','Count of States'],
    (12,5),
    10
)

plt.show()

# %% [markdown]
# **Composite/Total scores for ACT and SAT in 2019**

# %%
# To plot a histogram to compare the composite/total scores for ACT and SAT in 2017
subplot_histograms(
    act_sat_all,
    ['act_composite_2019','sat_total_2019'],
    ['ACT Composite Score in 2019','SAT Total Score in 2019'],
    ['Composite Score','Total Score'],
    ['Count of States','Count of States'],
    (12,5),
    10
)

plt.show()

# %% [markdown]
# Observations:
# - The distributions of ACT Composite Scores and SAT Total Scores from 2017 to 2019 mirror a bimodal distributions, with peaks in the range of:
#     - ACT Composite Scores: (i) 19 to 21, (ii) 23 to 25; median is ~21.3
#     - SAT Total Scores: (i) 1050 to 1100, (ii) 1200 to 1250; median is ~1100
# - This suggests a slightly right skew for both distrbutions of ACT Composite Scores and SAT Total Scores, where a greater proportion of students tend to be getting scores just above the passing mark.

# %% [markdown]
# #### We generally assume that data we sample from a population will be normally distributed. Do we observe this trend?

# %%
# To create histogram with Kernel Density Estimate (KDE) for composite/total scores for ACT and SAT scores in 2017

fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (10,6))

ax[0] = sns.distplot(act_sat_all['act_composite_2017'], ax = ax[0])
ax[0].set_title('Distribution of ACT Composite Score in 2017')
ax[0].set_xlabel('Score')
ax[0].set_ylabel('Proportion')
ax[0].tick_params(axis='x')
ax[0].tick_params(axis='y')

ax[1] = sns.distplot(act_sat_all['sat_total_2017'], ax = ax[1])
ax[1].set_title('Distribution of SAT Total Score in 2017')
ax[1].set_xlabel('Score')
ax[1].set_ylabel('Proportion')
ax[1].tick_params(axis='x')
ax[1].tick_params(axis='y')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Observations:
# - Based on the histograms in this section 3, it does not appear that the series follow a normal distribution.
# - Even with the distribution plot with Kernel Density Estimates (KDE), they do not follow a normal distribution.
# - The histograms of the participation rates earlier indicate that the data are not centrally distributed around a mean.
#     - It is also worth noting that while the participation rates are bound within 0 to 1.0, there are several states with near to 0% participation in SAT, and several other states with near to 10% participation in ACT.
#     - Such distributions are not consistent with that of a normal distribution.
# - On the contrary, while the mean test scores are under the Central Limit Theorem (CLT) such that the mean test scores would approach a normal distribution as sampling sizes increase, sampling bias is likely to exist.
#     - For instance, students in certain states have the liberty to decide if they would like to participate in the tests, or not.
#     - Particularly, it can be observed that there is a high negative correlation between participation rates and test scores, with participation rates ranging from 0% to 100%. We are unable to conclude that students in states with higher scores are better prepared to students in states with lower scores, since the participation rates greatly differ.
#     - For a more reasonable comparison, test scores would need to be compared within states with similar participation rates.

# %% [markdown]
# ### 3. Boxplots

# %% [markdown]
# #### (1) Comparing Participation rates for ACT and SAT from 2017 to 2019

# %%
# To create a boxplot for ACT and SAT participation rates, across 2017, 2018 and 2019

participation_rates = act_sat_all.loc[:,['act_participation_2017','act_participation_2018','act_participation_2019','sat_participation_2017','sat_participation_2018','sat_participation_2019']]
participation_rates = participation_rates.rename(columns={
    'act_participation_2017':'ACT 2017',
    'act_participation_2018':'ACT 2018',
    'act_participation_2019':'ACT 2019',
    'sat_participation_2017':'SAT 2017',
    'sat_participation_2018':'SAT 2018',
    'sat_participation_2019':'SAT 2019',
})
plt.figure(figsize=(8,8))
plt.title('Distribution of ACT and SAT Participation Rates, from 2017 to 2019')
sns.boxplot(data=participation_rates,orient='h');

# %% [markdown]
# Observations:
# - The median participation rates for ACT is declining over the years, from 69% in 2017, to 66% in 2018, and to 54% in 2019.
# - The median participation rates for SAT is increasing over the years, from 38% in 2017, to 52% in 2018, and to 54% in 2019.
# - This indicates a growing demand for SAT, albeit declining interest for ACT.

# %% [markdown]
# #### (2) Comparing Change in Participation rates for ACT and SAT from 2017 to 2019

# %%
# To create a boxplot for change in participations rates for ACT and SAT, between 2017 to 2018, and between 2018 to 2019

participation_rates = act_sat_all.loc[:,['act_participation_change_2017_2018','act_participation_change_2018_2019','sat_participation_change_2017_2018','sat_participation_change_2018_2019']]
participation_rates = participation_rates.rename(columns={
    'act_participation_change_2017_2018':'ACT 2017 to 2018',
    'act_participation_change_2018_2019':'ACT 2018 to 2019',
    'sat_participation_change_2017_2018':'SAT 2017 to 2018',
    'sat_participation_change_2018_2019':'SAT 2018 to 2019',
})
plt.figure(figsize=(7,7))
plt.title('Distribution of change in Participation Rates for ACT and SAT, from 2017 to 2019')
sns.boxplot(data=participation_rates,orient='h');

# %% [markdown]
# Observations:
# - Between 2017 to 2018:
#     - The median change in participation rates for ACT is -1%, with outliers from:
#         - Ohio (+25%), Nebraska (+16%), Colorado (-70%), Illinois (-50%), Alaska (-32%)
#     - The median change in participation rates for SAT is 1%, with outliers from:
#         - Illinois (+90%), Colorado (+89%), Rhode Island (+26%), West Virginia (+14%), New Jersey (+12%), New York (+12%), Florida (-27%)
#
# - Between 2018 to 2019:
#     - The median change in participation rates for ACT is -2%, with outliers from:
#         - South Carolina (-22%), Missouri (-18%), West Virginia (-16%), Florida (-12%)
#     - The median change in participation rates for SAT is 0%, with outliers from:
#         - West Virginia (+71%), Florida (+44%), Oklahoma (+14%), South Carolina (+13%)

# %% [markdown]
# #### (3) Comparing ACT Composite Scores from 2017 to 2019

# %%
# To create boxplot for ACT Composite scores, from 2017 to 2019

act_scores = act_sat_all.loc[:,['act_composite_2017','act_composite_2018','act_composite_2019']]
act_scores = act_scores.rename(columns={
    'act_composite_2017':'ACT 2017',
    'act_composite_2018':'ACT 2018',
    'act_composite_2019':'ACT 2019',
})
plt.figure(figsize=(5,5))
plt.title('Distribution of ACT Composite Scores, from 2017 to 2019')
sns.boxplot(data=act_scores,orient='h');

# %% [markdown]
# Observations:
# - The median composite scores for ACT is decreasing slightly over the years, from 21.4 in 2017, to 21.3 in 2018, and to 21.1 in 2019, despite declining participation rates in ACT.

# %% [markdown]
# #### (4) Comparing SAT Total Scores from 2017 to 2019

# %%
# To create boxplot for SAT total scores, from 2017 to 2019

sat_scores = act_sat_all.loc[:,['sat_total_2017','sat_total_2018','sat_total_2019']]
sat_scores = sat_scores.rename(columns={
    'sat_total_2017':'SAT 2017',
    'sat_total_2018':'SAT 2018',
    'sat_total_2019':'SAT 2019',
})
plt.figure(figsize=(5,5))
plt.title('Distribution of SAT Total Scores, from 2017 to 2019')
sns.boxplot(data=sat_scores,orient='h');

# %% [markdown]
# Observations:
# - The median composite scores for SAT is decreasing slightly over the years, from 1107 in 2017, to 1098 in 2018, and to 1097 in 2019. This could likely be due to the increasing participation rates in SAT.

# %% [markdown]
# ### 4. Scatterplots

# %%
# To create a scatterplot between two numeric variables

def subplot_scatterplots(column_1,column_2,xlabel,ylabel,title):
    f = plt.figure(figsize=(8,5))
    sns.set_style('whitegrid')
    sns.scatterplot(x=act_sat_all[column_1],y=act_sat_all[column_2])
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title);

# %% [markdown]
# #### (1) Comparing Participation rates between ACT and SAT from 2017 to 2019

# %% [markdown]
# **Participation rates for ACT and SAT in 2017**

# %%
# To create a scatterplot to compare the relationship between ACT and SAT participation rates in 2017
subplot_scatterplots('act_participation_2017','sat_participation_2017','ACT Participation Rate in 2017','SAT Participation Rate in 2017','Relationship between ACT and SAT Participation Rates in 2017')

# %% [markdown]
# **Participation rates for ACT and SAT in 2018**

# %%
# To create a scatterplot to compare the relationship between ACT and SAT participation rates in 2018
subplot_scatterplots('act_participation_2018','sat_participation_2018','ACT Participation Rate in 2018','SAT Participation Rate in 2018','Relationship between ACT and SAT Participation Rates in 2018')

# %% [markdown]
# **Participation rates for ACT and SAT in 2019**

# %%
# To create a scatterplot to compare the relationship between ACT and SAT participation rates in 2019
subplot_scatterplots('act_participation_2019','sat_participation_2019','ACT Participation Rate in 2019','SAT Participation Rate in 2019','Relationship between ACT and SAT Participation Rates in 2019')

# %% [markdown]
# Observations:
# - Across all 3 scatter plots in 2017, 2018 and 2019, it can be seen that ACT participation rate varies inversely with SAT participation rate, for instance:
#     - When participation in ACT is high (i.e. >70%), participation in SAT is low (i.e. <30%); the reverse holds true.
#     - It is likely that students would select one test over the other.
# - There are exceptions in which states such as Florida, Hawaii, North Carolina and South Carolina have relatively higher participation rates (>50%) on both ACT and SAT.

# %% [markdown]
# #### (2) Comparing Participation rates with Composite/Total scores for ACT and SAT from 2017 to 2019

# %% [markdown]
# **Participation rates with Composite/Total scores for ACT and SAT in 2017**

# %%
# To create a scatterplot to compare the relationship between ACT participation rate and composite score in 2017
subplot_scatterplots('act_participation_2017','act_composite_2017','ACT Participation Rate in 2017','ACT Composite Score in 2017','Relationship between ACT Participation Rate and Composite Score in 2017')

# %%
# To create a scatterplot to compare the relationship between SAT participation rate and total score in 2017
subplot_scatterplots('sat_participation_2017','sat_total_2017','SAT Participation Rate in 2017','SAT Total Score in 2017','Relationship between SAT Participation Rate and Total Score in 2017')

# %% [markdown]
# **Participation rates with Composite/Total scores for ACT and SAT in 2018**

# %%
# To create a scatterplot to compare the relationship between ACT participation rate and composite score in 2018
subplot_scatterplots('act_participation_2018','act_composite_2018','ACT Participation Rate in 2018','ACT Composite Score in 2018','Relationship between ACT Participation Rate and Composite Score in 2018')

# %%
# To create a scatterplot to compare the relationship between SAT participation rate and total score in 2018
subplot_scatterplots('sat_participation_2018','sat_total_2018','SAT Participation Rate in 2018','SAT Total Score in 2018','Relationship between SAT Participation Rate and Total Score in 2018')

# %% [markdown]
# **Participation rates with Composite/Total scores for ACT and SAT in 2019**

# %%
# To create a scatterplot to compare the relationship between ACT participation rate and composite score in 2019
subplot_scatterplots('act_participation_2019','act_composite_2019','ACT Participation Rate in 2019','ACT Composite Score in 2019','Relationship between ACT Participation Rate and Composite Score in 2019')

# %%
# To create a scatterplot to compare the relationship between SAT participation rate and total score in 2019
subplot_scatterplots('sat_participation_2019','sat_total_2019','SAT Participation Rate in 2019','SAT Total Score in 2019','Relationship between SAT Participation Rate and Total Score in 2019')

# %% [markdown]
# Observations:
# - Across all 3 scatter plots in 2017, 2018 and 2019, it can be seen that ACT and SAT participation rates vary inversely with the respective ACT composite scores and SAT total scores, where lower participation rates tend to translate into higher scores by states, and vice versa. For example:
#     - When participation in SAT is low (i.e. <20%), the total scores remain on the higher end at around 1200 to 1300, as seen in 2019.
#     - When participation in SAT is high (i.e. >80%), the total scores remain less than 1100, as observed in 2019.
#     - This is likely due to a selection bias where the high achieving students (a small subset of the entire base) would participate in both ACT and SAT tests, thus allowing the states to achieve higher scores despite the low participation rates.
# - There are exceptions in which states such as Oklahoma, which has a low score of 963 despite low participation rate of 22% in SAT in 2019.

# %% [markdown]
# #### (3) Comparing Composite/Total scores for ACT and SAT from 2017 to 2019

# %% [markdown]
# **Composite/Total scores for ACT and SAT between 2017 to 2018**

# %%
# To create a scatterplot to compare the relationship between ACT composite scores in 2017 and 2018
subplot_scatterplots('act_composite_2017','act_composite_2018','ACT Composite Score in 2017','ACT Composite Score in 2018','Relationship between ACT Composite Scores in 2017 and 2018')

# %% [markdown]
# Observations:
# - There is a high positive correlation between ACT Composite Scores in 2017 and 2018 for each states.
# - There are two outliers - Illinosis and Colorado - with significant increases in ACT Composite Scores between 2017 to 2018.
#     - This is likely due to the sizable reducation in ACT Participation rates (-70% for Colorado, -50% for Illinois), allowing for a higher mean score among students who still taking ACT.

# %%
# To create a scatterplot to compare the relationship between SAT total scores in 2017 and 2018
subplot_scatterplots('sat_total_2017','sat_total_2018','SAT Total Score in 2017','SAT Total Score in 2018','Relationship between SAT Total Scores in 2017 and 2018')

# %% [markdown]
# Observations:
# - There is a high positive correlation between SAT Total scores in 2017 and 2018 for each states.
# - There are two outliers - Illinosis and Colorado - with significant decreases in SAT Total Scores between 2017 to 2018.
#     - This is likely due to the sizable increase in SAT Participation rates (+90% for Illinois, +89% for Colorado), which might have diluted the quality of the mean score, though this does not entirely explain the scale of the decrease in score as the increase in participation rate for Illinois is proportionally larger than the fall in score.

# %% [markdown]
# **Composite/Total scores for ACT and SAT between 2018 to 2019**

# %%
# To create a scatterplot to compare the relationship between ACT composite scores in 2018 and 2019
subplot_scatterplots('act_composite_2018','act_composite_2019','ACT Composite Score in 2018','ACT Composite Score in 2019','Relationship between ACT Composite Scores in 2018 and 2019')

# %% [markdown]
# Observations:
# - There is a high positive correlation between ACT Composite Scores in 2018 and 2019 for each states.
# - There are no major outliers, as compared to that between 2017 and 2018.

# %%
# To create a scatterplot to compare the relationship between SAT total scores in 2018 and 2019
subplot_scatterplots('sat_total_2018','sat_total_2019','SAT Total Score in 2018','SAT Total Score in 2019','Relationship between SAT Total Scores in 2018 and 2019')

# %% [markdown]
# Observations:
# - There is a high positive correlation between SAT Total scores in 2018 and 2019 for each states.
# - There are two outliers with significant increases in SAT Total Scores between 2018 to 2019.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# By examining the trend in the median participation rates for ACT and SAT from 2017 to 2019, it is evident that participation rates for ACT is declining (from 69% in 2017 to 54% in 2019), while participation rates for SAT is increasing (from 38% in 2017 to 54% in 2019) as more states make it mandatory for students to take SAT. These states include Colorado, Illinois, Rhode Island and West Virginia.
# - With that, **We Believe In Education Pte Ltd** should focus on providing tuition programme in SAT, as it is likely that more students will take up SAT, thus increasing the demand for SAT tuition to improve scores.
#
# As for the states which are promising for the company to advertise its services to, as well as to award scholarships to deserving students, they can be segmented as follows:
# - **Target Market #1**: States with highest SAT participation rates, but lowest SAT scores
#     - States: **District of Columbia**, **Michigan**, **Connecticut**, **Delaware**, New Hampshire, **Maine**, **Idaho**, Rhode island *(note that states bolded have lowest SAT scores)*
#     - Reason: WIth SAT being mandated in these states, whilst the states have lower mean scores, there is a potential for stable and high demand for private tuition, as students aim to increase SAT scores and their chances to enrol in prestigious universities.
#
#
# - **Target Market #2**: States with lowest SAT participation rates, but highest SAT scores
#     - States: **North Dakota**, Mississippi, **Iowa**, Utah, South Dakota, **Nebraska**, **Wisconsin**, **Minnesota**, Wyoming *(note that states bolded have highest SAT scores)*
#     - Reason: While SAT is not mandatory in these states, there is a likelihood that many eligible students have yet to participate, due to the lack of awareness about SAT. Hence, there may be a potentially large market that's still untapped, eventually as students become aware of the benefits of SAT. In addition, these states tend to have higher mean total scores for SAT, likely formed by a small of high achieving students. Thus, scholarships can be channeled to these states as a mode for publicity, encouraging even more high achieving and deserving students (who may not have taken the test due to various reasons) to participate in SAT.
